# %% [markdown]
# # **Fine-tuning XLSR-Wav2Vec2 for Multi-Lingual ASR with 🤗 Transformers**

# %% [markdown]
# ## Pre-configuration

# %%
from ipywidgets import widgets

# %%
import os

# %%
language_code = 'sk'
language_name = 'slovakian'
base_model = "facebook/wav2vec2-large-xlsr-53"
pretrain_model = f"jimregan/wav2vec2-large-xlsr-{language_name}-demo"

data_dir = f"/workspace/data/{language_code}"
output_models_dir = f"/workspace/output_models/{language_code}/wav2vec2-large-xlsr-{language_name}-demo"

# %% [markdown]
# ## Presentation

# %% [markdown]
# Wav2Vec2 is a pretrained model for Automatic Speech Recognition (ASR) and was released in [September 2020](https://ai.facebook.com/blog/wav2vec-20-learning-the-structure-of-speech-from-raw-audio/) by Alexei Baevski, Michael Auli, and Alex Conneau.  Soon after the superior performance of Wav2Vec2 was demonstrated on the English ASR dataset LibriSpeech, *Facebook AI* presented XLSR-Wav2Vec2 (click [here](https://arxiv.org/abs/2006.13979)). XLSR stands for *cross-lingual  speech representations* and refers to XLSR-Wav2Vec2`s ability to learn speech representations that are useful across multiple languages.
#
# Similar to Wav2Vec2, XLSR-Wav2Vec2 learns powerful speech representations from hundreds of thousands of hours of speech in more than 50 languages of unlabeled speech. Similar, to [BERT's masked language modeling](http://jalammar.github.io/illustrated-bert/), the model learns contextualized speech representations by randomly masking feature vectors before passing them to a transformer network.
#
# ![wav2vec2_structure](https://raw.githubusercontent.com/patrickvonplaten/scientific_images/master/xlsr_wav2vec2.png)
#
# The authors show for the first time that massively pretraining an ASR model on cross-lingual unlabeled speech data, followed by language-specific fine-tuning on very little labeled data achieves state-of-the-art results. See Table 1-5 of the official [paper](https://arxiv.org/pdf/2006.13979.pdf).

# %% [markdown]
# In this notebook, we will give an in-detail explanation of how XLSR-Wav2Vec2's pretrained checkpoint can be fine-tuned on a low-resource ASR dataset of any language. Note that in this notebook, we will fine-tune XLSR-Wav2Vec2 without making use of a language model. It is much simpler and more efficient to use XLSR-Wav2Vec2 without a language model, but better results can be achieved by including a language model.
#
# For demonstration purposes, we fine-tune the [wav2vec2-large-xlsr-53](https://huggingface.co/facebook/wav2vec2-large-xlsr-53) on the low resource Turkish ASR dataset of [Common Voice](https://huggingface.co/datasets/common_voice) that contains just ~6h of validated training data.

# %% [markdown]
# XLSR-Wav2Vec2 is fine-tuned using Connectionist Temporal Classification (CTC), which is an algorithm that is used to train neural networks for sequence-to-sequence problems and mainly in Automatic Speech Recognition and handwriting recognition.
#
# I highly recommend reading the blog post [Sequence Modeling with CTC (2017)](https://distill.pub/2017/ctc/) very well-written blog post by Awni Hannun.

# %% [markdown]
# Before we start, let's install both `datasets` and `transformers` from master. Also, we need the `torchaudio` and `librosa` package to load audio files and the `jiwer` to evaluate our fine-tuned model using the [word error rate (WER)](https://huggingface.co/metrics/wer) metric ${}^1$.

# %% [markdown]
# ---
#
# ${}^1$ In the [paper](https://arxiv.org/pdf/2006.13979.pdf), the model was evaluated using the phoneme error rate (PER), but by far the most common metric in ASR is the word error rate (WER). To keep this notebook as general as possible we decided to evaluate the model using WER.

# %% [markdown]
# ## Prepare Data, Tokenizer, Feature Extractor

# %% [markdown]
# ASR models transcribe speech to text, which means that we both need a feature extractor that processes the speech signal to the model's input format, *e.g.* a feature vector, and a tokenizer that processes the model's output format to text.
#
# In 🤗 Transformers, the XLSR-Wav2Vec2 model is thus accompanied by both a tokenizer, called [Wav2Vec2CTCTokenizer](https://huggingface.co/transformers/master/model_doc/wav2vec2.html#wav2vec2ctctokenizer), and a feature extractor, called [Wav2Vec2FeatureExtractor](https://huggingface.co/transformers/master/model_doc/wav2vec2.html#wav2vec2featureextractor).
#
# Let's start by creating the tokenizer responsible for decoding the model's predictions.

# %% [markdown]
# ### Create Wav2Vec2CTCTokenizer

# %% [markdown]
# The [pretrained Wav2Vec2 checkpoint]( ) maps the speech signal to a sequence of context representations as illustrated in the figure above. A fine-tuned XLSR-Wav2Vec2 checkpoint needs to map this sequence of context representations to its corresponding transcription so that a linear layer has to be added on top of the transformer block (shown in yellow). This linear layer is used to classifies each context representation to a token class analogous how, *e.g.*, after pretraining a linear layer is added on top of BERT's embeddings for further classification - *cf.* with *"BERT"* section of this [blog post](https://huggingface.co/blog/warm-starting-encoder-decoder).
#
# The output size of this layer corresponds to the number of tokens in the vocabulary, which does **not** depend on XLSR-Wav2Vec2's pretraining task, but only on the labeled dataset used for fine-tuning. So in the first step, we will take a look at Common Voice and define a vocabulary based on the dataset's transcriptions.

# %% [markdown]
# First, let's go to [Common Voice](https://commonvoice.mozilla.org/en/datasets) and pick a language to fine-tune XLSR-Wav2Vec2 on. For this notebook, we will use Turkish.
#
# For each language-specific dataset, you can find a language code corresponding to your chosen language. On [Common Voice](https://commonvoice.mozilla.org/en/datasets), look for the field "Version". The language code then corresponds to the prefix before the underscore. For Turkish, *e.g.* the language code is `"tr"`.
#
# Great, now we can use 🤗 Datasets' simple API to download the data. The dataset name will be `"common_voice"`, the config name corresponds to the language code - `"tr"` in our case.

# %% [markdown]
# Common Voice has many different splits including `invalidated`, which refers to data that was not rated as "clean enough" to be considered useful. In this notebook, we will only make use of the splits `"train"`, `"validation"` and `"test"`.
#
# Because the Turkish dataset is so small, we will merge both the validation and training data into a training dataset and simply use the test data for validation.

# %%
from datasets import Dataset
dataset = Dataset.load_from_disk('/workspace/data/slovakian/tedxsk')

# %%
dataset = dataset.train_test_split(test_size=0.1)

# %%
tedxsk_train = dataset['train']
tedxsk_test = dataset['test']

# %% [markdown]
# Let's write a short function to display some random samples of the dataset and run it a couple of times to get a feeling for the transcriptions.

# %%
from datasets import ClassLabel
import random
import pandas as pd
from IPython.display import display, HTML

def show_random_elements(dataset, num_examples=10):
    assert num_examples <= len(dataset), "Can't pick more elements than there are in the dataset."
    picks = []
    for _ in range(num_examples):
        pick = random.randint(0, len(dataset)-1)
        while pick in picks:
            pick = random.randint(0, len(dataset)-1)
        picks.append(pick)
    
    df = pd.DataFrame(dataset[picks])
    display(HTML(df.to_html()))

# %%
show_random_elements(tedxsk_train.remove_columns(["path"]), num_examples=20)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>sentence</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>spraviť</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>môžte si kúpiť  jeho dvd-čko volá sa voodoo</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>a</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>som v tej chvíli najlepšie vedela</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>tak ja som vám dnes prišla porozprávať o našom projekte ďakujem_sused</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>pri tvorbe kolekcií pri  pri  prezentácii tých kolekcií</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>a práve preto som bol trošku aj  sps    spesiman* čo mi aj  prob  pomohlo</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>je to jednoducho</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>tieto funkcie si viem zakresliť</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>teda možno je tu nejaký</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>smrteľné poruchy srdcového rytmu rukami laika</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>a pýtame sa teda</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>tým že som sa začala stretávať s týmito zahraničnými študentami u nás na slovensku začala som vnímať aj slovensko inak</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>v biológii je obecne akceptované že živé organizmy</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>a vtedy  som  začala  utekať  s foťákom do  lesa  do polí</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>toto je zas pre prešovčanov lahôdka ak ste tu niekto</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>ako môže ovplyvňovať architektúru</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>a  je to kniha dokumentárneho charakteru</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>mechanizmy aké procesy generujú</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>a mm vďaka tomu že tomu vedenie  vedenie  galérie dalo   dalo  program</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Alright! The transcriptions look fairly clean. Having translated the transcribed sentences (I'm sadly not a native speaker in Turkish), it seems that the language corresponds more to written text than noisy dialogue. This makes sense taking into account that [Common Voice](https://huggingface.co/datasets/common_voice) is a crowd-sourced read speech corpus.

# %% [markdown]
# We can see that the transcriptions contain some special characters, such as `,.?!;:`. Without a language model, it is much harder to classify speech chunks to such special characters because they don't really correspond to a characteristic sound unit. *E.g.*, the letter `"s"` has a more or less clear sound, whereas the special character `"."` does not.
# Also in order to understand the meaning of a speech signal, it is usually not necessary to include special characters in the transcription.
#
# In addition, we normalize the text to only have lower case letters and append a word separator token at the end.

# %%
import re
chars_to_ignore_regex = '[\,\?\.\!\-\;\:\"\“\%\‘\”\�\']'

def remove_special_characters(batch):
    batch["sentence"] = re.sub(chars_to_ignore_regex, '', batch["sentence"]).lower() + " "
    return batch

# %%
tedxsk_train = tedxsk_train.map(remove_special_characters)
tedxsk_test = tedxsk_test.map(remove_special_characters)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=9700.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1078.0), HTML(value='')))

# %% [markdown]
# Good! This looks better. We have removed most special characters from transcriptions and normalized them to lower-case only.
#
# In CTC, it is common to classify speech chunks into letters, so we will do the same here.
# Let's extract all distinct letters of the training and test data and build our vocabulary from this set of letters.
#
# We write a mapping function that concatenates all transcriptions into one long transcription and then transforms the string into a set of chars.
# It is important to pass the argument `batched=True` to the `map(...)` function so that the mapping function has access to all transcriptions at once.

# %%
def extract_all_chars(batch):
  all_text = " ".join(batch["sentence"])
  vocab = list(set(all_text))
  return {"vocab": [vocab], "all_text": [all_text]}

# %%
vocab_train = tedxsk_train.map(extract_all_chars, batched=True, batch_size=-1, keep_in_memory=True, remove_columns=tedxsk_train.column_names)
vocab_test = tedxsk_test.map(extract_all_chars, batched=True, batch_size=-1, keep_in_memory=True, remove_columns=tedxsk_test.column_names)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=1.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1.0), HTML(value='')))

# %% [markdown]
# Now, we create the union of all distinct letters in the training dataset and test dataset and convert the resulting list into an enumerated dictionary.

# %%
vocab_list = list(set(vocab_train["vocab"][0]) | set(vocab_test["vocab"][0]))

# %%
vocab_dict = {v: k for k, v in enumerate(vocab_list)}
vocab_dict
# Out:
# {'z': 0,
#  'ä': 1,
#  'b': 2,
#  'ĺ': 3,
#  'n': 4,
#  'a': 5,
#  'č': 6,
#  'ô': 7,
#  'e': 8,
#  'ý': 9,
#  'r': 10,
#  'f': 11,
#  'k': 12,
#  'x': 13,
#  'w': 14,
#  'c': 15,
#  't': 16,
#  'o': 17,
#  'y': 18,
#  'v': 19,
#  'ď': 20,
#  ' ': 21,
#  'é': 22,
#  'l': 23,
#  'í': 24,
#  'ŕ': 25,
#  'ľ': 26,
#  'u': 27,
#  'ť': 28,
#  'ó': 29,
#  'ő': 30,
#  'á': 31,
#  'ö': 32,
#  's': 33,
#  'š': 34,
#  'h': 35,
#  'ž': 36,
#  'd': 37,
#  'p': 38,
#  'j': 39,
#  'q': 40,
#  'ú': 41,
#  'ě': 42,
#  'g': 43,
#  'i': 44,
#  'ň': 45,
#  'm': 46}

# %% [markdown]
# Cool, we see that all letters of the alphabet occur in the dataset (which is not really surprising) and we also extracted the special characters `" "` and `'`. Note that we did not exclude those special characters because:
#
# - The model has to learn to predict when a word is finished or else the model prediction would always be a sequence of chars which would make it impossible to separate words from each other.
# - From the transcriptions above it seems that words that include an apostrophe, such as `maktouf'un` do exist in Turkish, so I decided to keep the apostrophe in the dataset. This might be a wrong assumption though.
#
# One should always keep in mind that the data-preprocessing is a very important step before training your model. E.g., we don't want our model to differentiate between `a` and `A` just because we forgot to normalize the data. The difference between `a` and `A` does not depend on the "sound" of the letter at all, but more on grammatical rules - *e.g.* use a capitalized letter at the beginning of the sentence. So it is sensible to remove the difference between capitalized and non-capitalized letters so that the model has an easier time learning to transcribe speech.
#
# It is always advantageous to get help from a native speaker of the language you would like to transcribe to verify whether the assumptions you made are sensible, *e.g.* I should have made sure that keeping `'`, but removing other special characters is a sensible choice for Turkish.

# %% [markdown]
# To make it clearer that `" "` has its own token class, we give it a more visible character `|`. In addition, we also add an "unknown" token so that the model can later deal with characters not encountered in Common Voice's training set.
#
# Finally, we also add a padding token that corresponds to CTC's "*blank token*". The "blank token" is a core component of the CTC algorithm. For more information, please take a look at the "Alignment" section [here](https://distill.pub/2017/ctc/).

# %%
vocab_dict["|"] = vocab_dict[" "]
del vocab_dict[" "]

# %%
vocab_dict["[UNK]"] = len(vocab_dict)
vocab_dict["[PAD]"] = len(vocab_dict)
len(vocab_dict)
# Out:
# 49

# %% [markdown]
# Cool, now our vocabulary is complete and consists of 39 tokens, which means that the linear layer that we will add on top of the pretrained XLSR-Wav2Vec2 checkpoint will have an output dimension of 39.

# %% [markdown]
# Let's now save the vocabulary as a json file.

# %%
import json
with open('vocab.json', 'w') as vocab_file:
    json.dump(vocab_dict, vocab_file)

# %% [markdown]
# In a final step, we use the json file to instantiate an object of the `Wav2Vec2CTCTokenizer` class.

# %%
from transformers import Wav2Vec2CTCTokenizer

tokenizer = Wav2Vec2CTCTokenizer("./vocab.json", unk_token="[UNK]", pad_token="[PAD]", word_delimiter_token="|")

# %% [markdown]
# Next, we will create the feature extractor.

# %% [markdown]
# ### Create XLSR-Wav2Vec2 Feature Extractor

# %% [markdown]
# Speech is a continuous signal and to be treated by computers, it first has to be discretized, which is usually called **sampling**. The sampling rate hereby plays an important role in that it defines how many data points of the speech signal are measured per second. Therefore, sampling with a higher sampling rate results in a better approximation of the *real* speech signal but also necessitates more values per second.
#
# A pretrained checkpoint expects its input data to have been sampled more or less from the same distribution as the data it was trained on. The same speech signals sampled at two different rates have a very different distribution, *e.g.*, doubling the sampling rate results in data points being twice as long. Thus,
# before fine-tuning a pretrained checkpoint of an ASR model, it is crucial to verify that the sampling rate of the data that was used to pretrain the model matches the sampling rate of the dataset used to fine-tune the model.
#
# XLSR-Wav2Vec2 was pretrained on the audio data of [Babel](https://huggingface.co/datasets/librispeech_asr),
# [Multilingual LibriSpeech (MLS)](https://ai.facebook.com/blog/a-new-open-data-set-for-multilingual-speech-research/), and [Common Voice](https://huggingface.co/datasets/common_voice). Most of those datasets were sampled at 16kHz, so that Common Voice, sampled at 48kHz, has to be downsampled to 16kHz for training. Therefore, we will have to downsample our fine-tuning data to 16kHz in the following.

# %% [markdown]
# A XLSR-Wav2Vec2 feature extractor object requires the following parameters to be instantiated:
#
# - `feature_size`: Speech models take a sequence of feature vectors as an input. While the length of this sequence obviously varies, the feature size should not. In the case of Wav2Vec2, the feature size is 1 because the model was trained on the raw speech signal ${}^2$.
# - `sampling_rate`: The sampling rate at which the model is trained on.
# - `padding_value`: For batched inference, shorter inputs need to be padded with a specific value
# - `do_normalize`: Whether the input should be *zero-mean-unit-variance* normalized or not. Usually, speech models perform better when normalizing the input
# - `return_attention_mask`: Whether the model should make use of an `attention_mask` for batched inference. In general, XLSR-Wav2Vec2 models should **always** make use of the `attention_mask`.

# %%
from transformers import Wav2Vec2FeatureExtractor

feature_extractor = Wav2Vec2FeatureExtractor(feature_size=1, sampling_rate=16000, padding_value=0.0, do_normalize=True, return_attention_mask=True)

# %% [markdown]
# Great, XLSR-Wav2Vec2's feature extraction pipeline is thereby fully defined!
#
# To make the usage of XLSR-Wav2Vec2 as user-friendly as possible, the feature extractor and tokenizer are *wrapped* into a single `Wav2Vec2Processor` class so that one only needs a `model` and `processor` object.

# %%
from transformers import Wav2Vec2Processor

processor = Wav2Vec2Processor(feature_extractor=feature_extractor, tokenizer=tokenizer)

# %% [markdown]
# If one wants to re-use the just created processor and the fine-tuned model of this notebook, one can mount his/her google drive to the notebook and save all relevant files there. To do so, please uncomment the following lines.
#
# We will give the fine-tuned model the name `"wav2vec2-large-xlsr-turkish-demo"`.

# %%
processor.save_pretrained(output_models_dir)

# %% [markdown]
# Next, we can prepare the dataset.

# %% [markdown]
# ### Preprocess Data
#
# So far, we have not looked at the actual values of the speech signal but just kept the path to its file in the dataset. `XLSR-Wav2Vec2` expects the audio file in the format of a 1-dimensional array, so in the first step, let's load all audio files into the dataset object.
#
# Let's first check the serialization format of the downloaded audio files by looking at the first training sample.

# %%
tedxsk_train[0]
# Out:
# {'path': '/workspace/data/slovakian/training/837_tedxsk_male_837_tedxsk_143.302_145.107.wav',
#  'sentence': 'že idem napísať životopis '}

# %% [markdown]
# Alright, the audio file is saved in the `.mp3` format. The `.mp3` format is usually not the easiest format to deal with. We found that the [`torchaudio`](https://pytorch.org/audio/stable/index.html) library works best for reading in `.mp3` data.
#
# An audio file usually stores both its values and the sampling rate with which the speech signal was digitalized. We want to store both in the dataset and write a `map(...)` function accordingly.

# %%
import torchaudio

def speech_file_to_array_fn(batch):
    speech_array, sampling_rate = torchaudio.load(batch["path"])
    batch["speech"] = speech_array[0].numpy()
    batch["sampling_rate"] = sampling_rate
    batch["target_text"] = batch["sentence"]
    return batch

# %%
tedxsk_train = tedxsk_train.map(speech_file_to_array_fn, remove_columns=tedxsk_train.column_names)
tedxsk_test = tedxsk_test.map(speech_file_to_array_fn, remove_columns=tedxsk_test.column_names)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=9700.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1078.0), HTML(value='')))

# %% [markdown]
# Great, now we've successfully read in all the audio files, but since we know that Common Voice is sampled at 48kHz, we need to resample the audio files to 16kHz.
#
# Let's make use of the [`librosa`](https://github.com/librosa/librosa) library to downsample the data.

# %%
import librosa
import numpy as np

def resample(batch):
    #batch["speech"] = librosa.resample(np.asarray(batch["speech"]), ["sampling_rate"], 16_000)
    batch["speech"] = np.asarray(batch["speech"])
    
    batch["sampling_rate"] = 16_000
    return batch

# %%
tedxsk_train = tedxsk_train.map(resample, num_proc=13)
tedxsk_test = tedxsk_test.map(resample, num_proc=13)
# Out:
# HBox(children=(FloatProgress(value=0.0, description='#0', max=747.0, style=ProgressStyle(description_width='in…
# HBox(children=(FloatProgress(value=0.0, description='#1', max=747.0, style=ProgressStyle(description_width='in…
# HBox(children=(FloatProgress(value=0.0, description='#3', max=746.0, style=ProgressStyle(description_width='in…
# HBox(children=(FloatProgress(value=0.0, description='#2', max=746.0, style=ProgressStyle(description_width='in…
# HBox(children=(FloatProgress(value=0.0, description='#4', max=746.0, style=ProgressStyle(description_width='in…
# HBox(children=(FloatProgress(value=0.0, description='#5', max=746.0, style=ProgressStyle(description_width='in…
# HBox(children=(FloatProgress(value=0.0, description='#7', max=746.0, style=ProgressStyle(description_width='in…
# HBox(children=(FloatProgress(value=0.0, description='#6', max=746.0, style=ProgressStyle(description_width='in…
# HBox(children=(FloatProgress(value=0.0, description='#11', max=746.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='#10', max=746.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='#12', max=746.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='#9', max=746.0, style=ProgressStyle(description_width='in…
# HBox(children=(FloatProgress(value=0.0, description='#8', max=746.0, style=ProgressStyle(description_width='in…
# HBox(children=(FloatProgress(value=0.0, description='#0', max=83.0, style=ProgressStyle(description_width='ini…
# HBox(children=(FloatProgress(value=0.0, description='#1', max=83.0, style=ProgressStyle(description_width='ini…
# HBox(children=(FloatProgress(value=0.0, description='#2', max=83.0, style=ProgressStyle(description_width='ini…
# HBox(children=(FloatProgress(value=0.0, description='#4', max=83.0, style=ProgressStyle(description_width='ini…
# HBox(children=(FloatProgress(value=0.0, description='#6', max=83.0, style=ProgressStyle(description_width='ini…
# HBox(children=(FloatProgress(value=0.0, description='#3', max=83.0, style=ProgressStyle(description_width='ini…
# HBox(children=(FloatProgress(value=0.0, description='#7', max=83.0, style=ProgressStyle(description_width='ini…
# HBox(children=(FloatProgress(value=0.0, description='#5', max=83.0, style=ProgressStyle(description_width='ini…
# HBox(children=(FloatProgress(value=0.0, description='#9', max=83.0, style=ProgressStyle(description_width='ini…
# HBox(children=(FloatProgress(value=0.0, description='#11', max=83.0, style=ProgressStyle(description_width='in…
# HBox(children=(FloatProgress(value=0.0, description='#12', max=82.0, style=ProgressStyle(description_width='in…
# HBox(children=(FloatProgress(value=0.0, description='#10', max=83.0, style=ProgressStyle(description_width='in…
# HBox(children=(FloatProgress(value=0.0, description='#8', max=83.0, style=ProgressStyle(description_width='ini…

# %% [markdown]
# This seemed to have worked! Let's listen to a couple of audio files to better understand the dataset and verify that the audio was correctly loaded.
#
# **Note**: *You can click the following cell a couple of times to listen to different speech samples.*

# %%
import IPython.display as ipd
import numpy as np
import random

rand_int = random.randint(0, len(tedxsk_train)-1)

ipd.Audio(data=np.asarray(tedxsk_train[rand_int]["speech"]), autoplay=True, rate=16000)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# It can be heard, that the speakers change along with their speaking rate, accent, and background environment, etc. Overall, the recordings sound acceptably clear though, which is to be expected from a crowd-sourced read speech corpus.
#
# Let's do a final check that the data is correctly prepared, by printing the shape of the speech input, its transcription, and the corresponding sampling rate.
#
# **Note**: *You can click the following cell a couple of times to verify multiple samples.*

# %%
rand_int = random.randint(0, len(tedxsk_train)-1)

print("Target text:", tedxsk_train[rand_int]["target_text"])
print("Input array shape:", np.asarray(tedxsk_train[rand_int]["speech"]).shape)
print("Sampling rate:", tedxsk_train[rand_int]["sampling_rate"])
# Out:
# Target text: aj keď  častokrát   najmä malé deti sa vyjadrujú inak ako my dospelí
# Input array shape: (86624,)
# Sampling rate: 16000

# %% [markdown]
# Good! Everything looks fine - the data is a 1-dimensional array, the sampling rate always corresponds to 16kHz, and the target text is normalized.

# %% [markdown]
# Finally, we can process the dataset to the format expected by the model for training. We will again make use of the `map(...)` function.
#
# First, we check that the data samples have the same sampling rate of 16kHz.
# Second, we extract the `input_values` from the loaded audio file. In our case, this includes only normalization, but for other speech models, this step could correspond to extracting, *e.g.* [Log-Mel features](https://en.wikipedia.org/wiki/Mel-frequency_cepstrum).
# Third, we encode the transcriptions to label ids.
#
# **Note**: This mapping function is a good example of how the `Wav2Vec2Processor` class should be used. In "normal" context, calling `processor(...)` is redirected to `Wav2Vec2FeatureExtractor`'s call method. When wrapping the processor into the `as_target_processor` context, however, the same method is redirected to `Wav2Vec2CTCTokenizer`'s call method.
# For more information please check the [docs](https://huggingface.co/transformers/master/model_doc/wav2vec2.html#transformers.Wav2Vec2Processor.__call__).

# %%
def prepare_dataset(batch):
    # check that all files have the correct sampling rate
    assert (
        len(set(batch["sampling_rate"])) == 1
    ), f"Make sure all inputs have the same sampling rate of {processor.feature_extractor.sampling_rate}."

    batch["input_values"] = processor(batch["speech"], sampling_rate=batch["sampling_rate"][0]).input_values
    
    with processor.as_target_processor():
        batch["labels"] = processor(batch["target_text"]).input_ids
    return batch

# %%
tedxsk_train = tedxsk_train.map(prepare_dataset, remove_columns=tedxsk_train.column_names, batch_size=8, num_proc=12, batched=True)
tedxsk_test = tedxsk_test.map(prepare_dataset, remove_columns=tedxsk_test.column_names, batch_size=8, num_proc=12, batched=True)
# Out:
# HBox(children=(FloatProgress(value=0.0, description='#8', max=101.0, style=ProgressStyle(description_width='in…
# HBox(children=(FloatProgress(value=0.0, description='#7', max=101.0, style=ProgressStyle(description_width='in…
# HBox(children=(FloatProgress(value=0.0, description='#9', max=101.0, style=ProgressStyle(description_width='in…
# HBox(children=(FloatProgress(value=0.0, description='#11', max=101.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='#10', max=101.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='#6', max=101.0, style=ProgressStyle(description_width='in…
# HBox(children=(FloatProgress(value=0.0, description='#1', max=102.0, style=ProgressStyle(description_width='in…
# HBox(children=(FloatProgress(value=0.0, description='#5', max=101.0, style=ProgressStyle(description_width='in…
# HBox(children=(FloatProgress(value=0.0, description='#0', max=102.0, style=ProgressStyle(description_width='in…
# HBox(children=(FloatProgress(value=0.0, description='#2', max=102.0, style=ProgressStyle(description_width='in…
# HBox(children=(FloatProgress(value=0.0, description='#3', max=102.0, style=ProgressStyle(description_width='in…
# HBox(children=(FloatProgress(value=0.0, description='#4', max=101.0, style=ProgressStyle(description_width='in…
# HBox(children=(FloatProgress(value=0.0, description='#6', max=12.0, style=ProgressStyle(description_width='ini…
# HBox(children=(FloatProgress(value=0.0, description='#0', max=12.0, style=ProgressStyle(description_width='ini…
# HBox(children=(FloatProgress(value=0.0, description='#8', max=12.0, style=ProgressStyle(description_width='ini…
# HBox(children=(FloatProgress(value=0.0, description='#7', max=12.0, style=ProgressStyle(description_width='ini…
# HBox(children=(FloatProgress(value=0.0, description='#9', max=12.0, style=ProgressStyle(description_width='ini…
# HBox(children=(FloatProgress(value=0.0, description='#11', max=12.0, style=ProgressStyle(description_width='in…
# HBox(children=(FloatProgress(value=0.0, description='#4', max=12.0, style=ProgressStyle(description_width='ini…
# HBox(children=(FloatProgress(value=0.0, description='#1', max=12.0, style=ProgressStyle(description_width='ini…
# HBox(children=(FloatProgress(value=0.0, description='#2', max=12.0, style=ProgressStyle(description_width='ini…
# HBox(children=(FloatProgress(value=0.0, description='#10', max=12.0, style=ProgressStyle(description_width='in…
# HBox(children=(FloatProgress(value=0.0, description='#3', max=12.0, style=ProgressStyle(description_width='ini…
# HBox(children=(FloatProgress(value=0.0, description='#5', max=12.0, style=ProgressStyle(description_width='ini…

# %% [markdown]
# ## Training
#
# The data is processed so that we are ready to start setting up the training pipeline. We will make use of 🤗's [Trainer](https://huggingface.co/transformers/master/main_classes/trainer.html?highlight=trainer) for which we essentially need to do the following:
#
# - Define a data collator. In contrast to most NLP models, XLSR-Wav2Vec2 has a much larger input length than output length. *E.g.*, a sample of input length 50000 has an output length of no more than 100. Given the large input sizes, it is much more efficient to pad the training batches dynamically meaning that all training samples should only be padded to the longest sample in their batch and not the overall longest sample. Therefore, fine-tuning XLSR-Wav2Vec2 requires a special padding data collator, which we will define below
#
# - Evaluation metric. During training, the model should be evaluated on the word error rate. We should define a `compute_metrics` function accordingly
#
# - Load a pretrained checkpoint. We need to load a pretrained checkpoint and configure it correctly for training.
#
# - Define the training configuration.
#
# After having fine-tuned the model, we will correctly evaluate it on the test data and verify that it has indeed learned to correctly transcribe speech.

# %% [markdown]
# ### Set-up Trainer
#
# Let's start by defining the data collator. The code for the data collator was copied from [this example](https://github.com/huggingface/transformers/blob/9a06b6b11bdfc42eea08fa91d0c737d1863c99e3/examples/research_projects/wav2vec2/run_asr.py#L81).
#
# Without going into too many details, in contrast to the common data collators, this data collator treats the `input_values` and `labels` differently and thus applies to separate padding functions on them (again making use of XLSR-Wav2Vec2's context manager). This is necessary because in speech input and output are of different modalities meaning that they should not be treated by the same padding function.
# Analogous to the common data collators, the padding tokens in the labels with `-100` so that those tokens are **not** taken into account when computing the loss.

# %%
import torch

from dataclasses import dataclass, field
from typing import Any, Dict, List, Optional, Union

@dataclass
class DataCollatorCTCWithPadding:
    """
    Data collator that will dynamically pad the inputs received.
    Args:
        processor (:class:`~transformers.Wav2Vec2Processor`)
            The processor used for proccessing the data.
        padding (:obj:`bool`, :obj:`str` or :class:`~transformers.tokenization_utils_base.PaddingStrategy`, `optional`, defaults to :obj:`True`):
            Select a strategy to pad the returned sequences (according to the model's padding side and padding index)
            among:
            * :obj:`True` or :obj:`'longest'`: Pad to the longest sequence in the batch (or no padding if only a single
              sequence if provided).
            * :obj:`'max_length'`: Pad to a maximum length specified with the argument :obj:`max_length` or to the
              maximum acceptable input length for the model if that argument is not provided.
            * :obj:`False` or :obj:`'do_not_pad'` (default): No padding (i.e., can output a batch with sequences of
              different lengths).
        max_length (:obj:`int`, `optional`):
            Maximum length of the ``input_values`` of the returned list and optionally padding length (see above).
        max_length_labels (:obj:`int`, `optional`):
            Maximum length of the ``labels`` returned list and optionally padding length (see above).
        pad_to_multiple_of (:obj:`int`, `optional`):
            If set will pad the sequence to a multiple of the provided value.
            This is especially useful to enable the use of Tensor Cores on NVIDIA hardware with compute capability >=
            7.5 (Volta).
    """

    processor: Wav2Vec2Processor
    padding: Union[bool, str] = True
    max_length: Optional[int] = None
    max_length_labels: Optional[int] = None
    pad_to_multiple_of: Optional[int] = None
    pad_to_multiple_of_labels: Optional[int] = None

    def __call__(self, features: List[Dict[str, Union[List[int], torch.Tensor]]]) -> Dict[str, torch.Tensor]:
        # split inputs and labels since they have to be of different lenghts and need
        # different padding methods
        input_features = [{"input_values": feature["input_values"]} for feature in features]
        label_features = [{"input_ids": feature["labels"]} for feature in features]

        batch = self.processor.pad(
            input_features,
            padding=self.padding,
            max_length=self.max_length,
            pad_to_multiple_of=self.pad_to_multiple_of,
            return_tensors="pt",
        )
        with self.processor.as_target_processor():
            labels_batch = self.processor.pad(
                label_features,
                padding=self.padding,
                max_length=self.max_length_labels,
                pad_to_multiple_of=self.pad_to_multiple_of_labels,
                return_tensors="pt",
            )

        # replace padding with -100 to ignore loss correctly
        labels = labels_batch["input_ids"].masked_fill(labels_batch.attention_mask.ne(1), -100)

        batch["labels"] = labels

        return batch

# %%
data_collator = DataCollatorCTCWithPadding(processor=processor, padding=True)

# %% [markdown]
# Next, the evaluation metric is defined. As mentioned earlier, the
# predominant metric in ASR is the word error rate (WER), hence we will use it in this notebook as well.

# %%
from datasets import load_metric
wer_metric = load_metric("wer")

# %% [markdown]
# The model will return a sequence of logit vectors:
# $\mathbf{y}_1, \ldots, \mathbf{y}_m$ with $\mathbf{y}_1 = f_{\theta}(x_1, \ldots, x_n)[0]$ and $n >> m$.
#
# A logit vector $\mathbf{y}_1$ contains the log-odds for each word in the vocabulary we defined earlier, thus $\text{len}(\mathbf{y}_i) =$ `config.vocab_size`. We are interested in the most likely prediction of the model and thus take the `argmax(...)` of the logits. Also, we transform the encoded labels back to the original string by replacing `-100` with the `pad_token_id` and decoding the ids while making sure that consecutive tokens are **not** grouped to the same token in CTC style ${}^1$.

# %%
def compute_metrics(pred):
    pred_logits = pred.predictions
    pred_ids = np.argmax(pred_logits, axis=-1)

    pred.label_ids[pred.label_ids == -100] = processor.tokenizer.pad_token_id

    pred_str = processor.batch_decode(pred_ids)
    # we do not want to group tokens when computing the metrics
    label_str = processor.batch_decode(pred.label_ids, group_tokens=False)

    wer = wer_metric.compute(predictions=pred_str, references=label_str)

    return {"wer": wer}

# %% [markdown]
# Now, we can load the pretrained `XLSR-Wav2Vec2` checkpoint. The tokenizer's `pad_token_id` must be to define the model's `pad_token_id` or in the case of `Wav2Vec2ForCTC` also CTC's *blank token* ${}^2$. To save GPU memory, we enable PyTorch's [gradient checkpointing](https://pytorch.org/docs/stable/checkpoint.html) and also set the loss reduction to "*mean*".
#
# Because the dataset is quite small (~6h of training data) and because Common Voice is quite noisy, fine-tuning Facebook's [wav2vec2-large-xlsr-53 checkpoint](https://huggingface.co/facebook/wav2vec2-large-xlsr-53) seems to require some hyper-parameter tuning. Therefore, I had to play around a bit with different values for dropout, [SpecAugment](https://arxiv.org/abs/1904.08779)'s masking dropout rate, layer dropout, and the learning rate until training seemed to be stable enough.
#
# **Note**: When using this notebook to train XLSR-Wav2Vec2 on another language of Common Voice those hyper-parameter settings might not work very well. Feel free to adapt those depending on your use case.

# %%
from transformers import Wav2Vec2ForCTC

model = Wav2Vec2ForCTC.from_pretrained(
    "facebook/wav2vec2-large-xlsr-53", 
    attention_dropout=0.1,
    hidden_dropout=0.1,
    feat_proj_dropout=0.0,
    mask_time_prob=0.05,
    layerdrop=0.1,
    gradient_checkpointing=True, 
    ctc_loss_reduction="mean", 
    pad_token_id=processor.tokenizer.pad_token_id,
    vocab_size=len(processor.tokenizer)
)
# Out:
# Some weights of Wav2Vec2ForCTC were not initialized from the model checkpoint at facebook/wav2vec2-large-xlsr-53 and are newly initialized: ['lm_head.weight', 'lm_head.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %% [markdown]
# The first component of XLSR-Wav2Vec2 consists of a stack of CNN layers that are used to extract acoustically meaningful - but contextually independent - features from the raw speech signal. This part of the model has already been sufficiently trained during pretraining and as stated in the [paper](https://arxiv.org/pdf/2006.13979.pdf) does not need to be fine-tuned anymore.
# Thus, we can set the `requires_grad` to `False` for all parameters of the *feature extraction* part.

# %%
model.freeze_feature_extractor()

# %% [markdown]
# In a final step, we define all parameters related to training.
# To give more explanation on some of the parameters:
# - `group_by_length` makes training more efficient by grouping training samples of similar input length into one batch. This can significantly speed up training time by heavily reducing the overall number of useless padding tokens that are passed through the model
# - `learning_rate` and `weight_decay` were heuristically tuned until fine-tuning has become stable. Note that those parameters strongly depend on the Common Voice dataset and might be suboptimal for other speech datasets.
#
# For more explanations on other parameters, one can take a look at the [docs](https://huggingface.co/transformers/master/main_classes/trainer.html?highlight=trainer#trainingarguments).
#
# **Note**: If one wants to save the trained models in his/her google drive the commented-out `output_dir` can be used instead.

# %%
from transformers import TrainingArguments

training_args = TrainingArguments(
  output_dir=output_models_dir,
  group_by_length=True,
  per_device_train_batch_size=16,
  gradient_accumulation_steps=2,
  evaluation_strategy="steps",
  num_train_epochs=30,
  fp16=True,
  save_steps=400,
  eval_steps=400,
  logging_steps=400,
  learning_rate=3e-4,
  warmup_steps=500,
  save_total_limit=2,
)

# %% [markdown]
# Now, all instances can be passed to Trainer and we are ready to start training!

# %%
from transformers import Trainer

trainer = Trainer(
    model=model,
    data_collator=data_collator,
    args=training_args,
    compute_metrics=compute_metrics,
    train_dataset=tedxsk_train,
    eval_dataset=tedxsk_test,
    tokenizer=processor.feature_extractor,
)

# %% [markdown]
# ---
#
# ${}^1$ To allow models to become independent of the speaker rate, in CTC, consecutive tokens that are identical are simply grouped as a single token. However, the encoded labels should not be grouped when decoding since they don't correspond to the predicted tokens of the model, which is why the `group_tokens=False` parameter has to be passed. If we wouldn't pass this parameter a word like `"hello"` would incorrectly be encoded, and decoded as `"helo"`.
#
# ${}^2$ The blank token allows the model to predict a word, such as `"hello"` by forcing it to insert the blank token between the two l's. A CTC-conform prediction of `"hello"` of our model would be `[PAD] [PAD] "h" "e" "e" "l" "l" [PAD] "l" "o" "o" [PAD]`.

# %% [markdown]
# ### Training

# %% [markdown]
# Training will take between 180 and 240 minutes depending on the GPU allocated to this notebook. While the trained model yields somewhat satisfying results on *Common Voice*'s test data of Turkish, it is by no means an optimally fine-tuned model. The purpose of this notebook is to demonstrate how XLSR-Wav2Vec2's [checkpoint](https://huggingface.co/facebook/wav2vec2-large-xlsr-53) can be fine-tuned on a low-resource ASR dataset.
#
# In case you want to use this google colab to fine-tune your model, you should make sure that your training doesn't stop due to inactivity. A simple hack to prevent this is to paste the following code into the console of this tab (*right mouse click -> inspect -> Console tab and insert code*).

# %% [markdown]
# ```javascript
# function ConnectButton(){
#     console.log("Connect pushed");
#     document.querySelector("#top-toolbar > colab-connect-button").shadowRoot.querySelector("#connect").click()
# }
# setInterval(ConnectButton,60000);
# ```

# %%
trainer.train()
# Out:
# wandb: Currently logged in as: jimregan (use `wandb login --relogin` to force relogin)
#                 Tracking run with wandb version 0.10.24<br/>
#                 Syncing run <strong style="color:#cdcd00">/workspace/output_models/sk/wav2vec2-large-xlsr-slovakian-demo</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/jimregan/huggingface" target="_blank">https://wandb.ai/jimregan/huggingface</a><br/>
#                 Run page: <a href="https://wandb.ai/jimregan/huggingface/runs/36wjsjrj" target="_blank">https://wandb.ai/jimregan/huggingface/runs/36wjsjrj</a><br/>
#                 Run data is saved locally in <code>/workspace/wav2vec2-sprint/slovakian/wandb/run-20210331_132033-36wjsjrj</code><br/><br/>
# /opt/conda/lib/python3.7/site-packages/torch/optim/lr_scheduler.py:136: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   "https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate", UserWarning)
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#         </style>
#
#       <progress value='9090' max='9090' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [9090/9090 8:13:47, Epoch 29/30]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Wer</th>
#       <th>Runtime</th>
#       <th>Samples Per Second</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>400</td>
#       <td>5.711300</td>
#       <td>3.177376</td>
#       <td>0.993910</td>
#       <td>96.320200</td>
#       <td>11.192000</td>
#     </tr>
#     <tr>
#       <td>800</td>
#       <td>1.788700</td>
#       <td>0.577013</td>
#       <td>0.645582</td>
#       <td>99.098100</td>
#       <td>10.878000</td>
#     </tr>
#     <tr>
#       <td>1200</td>
#       <td>0.628900</td>
#       <td>0.407667</td>
#       <td>0.507960</td>
#       <td>99.472600</td>
#       <td>10.837000</td>
#     </tr>
#     <tr>
#       <td>1600</td>
#       <td>0.447100</td>
#       <td>0.342979</td>
#       <td>0.421626</td>
#       <td>97.846400</td>
#       <td>11.017000</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.354600</td>
#       <td>0.326408</td>
#       <td>0.397906</td>
#       <td>98.551500</td>
#       <td>10.938000</td>
#     </tr>
#     <tr>
#       <td>2400</td>
#       <td>0.310000</td>
#       <td>0.314102</td>
#       <td>0.374185</td>
#       <td>98.184800</td>
#       <td>10.979000</td>
#     </tr>
#     <tr>
#       <td>2800</td>
#       <td>0.260200</td>
#       <td>0.316124</td>
#       <td>0.364996</td>
#       <td>99.503900</td>
#       <td>10.834000</td>
#     </tr>
#     <tr>
#       <td>3200</td>
#       <td>0.234900</td>
#       <td>0.296567</td>
#       <td>0.351426</td>
#       <td>101.961300</td>
#       <td>10.573000</td>
#     </tr>
#     <tr>
#       <td>3600</td>
#       <td>0.216900</td>
#       <td>0.300049</td>
#       <td>0.344268</td>
#       <td>101.801200</td>
#       <td>10.589000</td>
#     </tr>
#     <tr>
#       <td>4000</td>
#       <td>0.192800</td>
#       <td>0.293388</td>
#       <td>0.331232</td>
#       <td>101.768000</td>
#       <td>10.593000</td>
#     </tr>
#     <tr>
#       <td>4400</td>
#       <td>0.175300</td>
#       <td>0.305532</td>
#       <td>0.326851</td>
#       <td>102.330100</td>
#       <td>10.535000</td>
#     </tr>
#     <tr>
#       <td>4800</td>
#       <td>0.154300</td>
#       <td>0.316432</td>
#       <td>0.327599</td>
#       <td>103.745000</td>
#       <td>10.391000</td>
#     </tr>
#     <tr>
#       <td>5200</td>
#       <td>0.148700</td>
#       <td>0.321041</td>
#       <td>0.316594</td>
#       <td>105.719700</td>
#       <td>10.197000</td>
#     </tr>
#     <tr>
#       <td>5600</td>
#       <td>0.136200</td>
#       <td>0.335178</td>
#       <td>0.316701</td>
#       <td>106.949500</td>
#       <td>10.080000</td>
#     </tr>
#     <tr>
#       <td>6000</td>
#       <td>0.125400</td>
#       <td>0.318684</td>
#       <td>0.307725</td>
#       <td>105.279600</td>
#       <td>10.239000</td>
#     </tr>
#     <tr>
#       <td>6400</td>
#       <td>0.112500</td>
#       <td>0.329666</td>
#       <td>0.309542</td>
#       <td>107.290300</td>
#       <td>10.048000</td>
#     </tr>
#     <tr>
#       <td>6800</td>
#       <td>0.112700</td>
#       <td>0.325651</td>
#       <td>0.304092</td>
#       <td>106.857300</td>
#       <td>10.088000</td>
#     </tr>
#     <tr>
#       <td>7200</td>
#       <td>0.103100</td>
#       <td>0.322232</td>
#       <td>0.303558</td>
#       <td>108.069800</td>
#       <td>9.975000</td>
#     </tr>
#     <tr>
#       <td>7600</td>
#       <td>0.095200</td>
#       <td>0.335065</td>
#       <td>0.299818</td>
#       <td>109.651500</td>
#       <td>9.831000</td>
#     </tr>
#     <tr>
#       <td>8000</td>
#       <td>0.093200</td>
#       <td>0.335632</td>
#       <td>0.297468</td>
#       <td>108.347800</td>
#       <td>9.949000</td>
#     </tr>
#     <tr>
#       <td>8400</td>
#       <td>0.087900</td>
#       <td>0.332539</td>
#       <td>0.292553</td>
#       <td>110.075000</td>
#       <td>9.793000</td>
#     </tr>
#     <tr>
#       <td>8800</td>
#       <td>0.089300</td>
#       <td>0.335105</td>
#       <td>0.293301</td>
#       <td>110.849500</td>
#       <td>9.725000</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=9090, training_loss=0.5121616128516538, metrics={'train_runtime': 29637.8194, 'train_samples_per_second': 0.307, 'total_flos': 3.1363403880260616e+19, 'epoch': 30.0, 'init_mem_cpu_alloc_delta': 10368983, 'init_mem_gpu_alloc_delta': 1261956096, 'init_mem_cpu_peaked_delta': 18306, 'init_mem_gpu_peaked_delta': 0, 'train_mem_cpu_alloc_delta': 52014322, 'train_mem_gpu_alloc_delta': 3778741760, 'train_mem_cpu_peaked_delta': 130829063, 'train_mem_gpu_peaked_delta': 4725795840})

# %%
trainer.save_model('/workspace/output_models/sk')
tokenizer.save_pretrained('/workspace/output_models/sk')
# Out:
# ('/workspace/output_models/sk/tokenizer_config.json',
#  '/workspace/output_models/sk/special_tokens_map.json',
#  '/workspace/output_models/sk/vocab.json',
#  '/workspace/output_models/sk/added_tokens.json')

# %%
import torch
import torchaudio
from datasets import load_dataset, load_metric
from transformers import Wav2Vec2ForCTC, Wav2Vec2Processor
import re
dataset = Dataset.load_from_disk('/workspace/data/slovakian/tedxsk')
dataset = dataset.train_test_split(test_size=0.1)
test_dataset = dataset['test']
wer = load_metric("wer")
processor = Wav2Vec2Processor.from_pretrained("/workspace/output_models/sk")
model = Wav2Vec2ForCTC.from_pretrained("/workspace/output_models/sk2")
model.to("cuda")
chars_to_ignore_regex = '[\,\?\.\!\-\;\:\"\“\%\‘\”\�\']'
resampler = torchaudio.transforms.Resample(16_000, 16_000)

def speech_file_to_array_fn(batch):
    batch["sentence"] = re.sub(chars_to_ignore_regex, '', batch["sentence"]).lower()
    speech_array, sampling_rate = torchaudio.load(batch["path"])
    batch["speech"] = resampler(speech_array).squeeze().numpy()
    return batch

test_dataset = test_dataset.map(speech_file_to_array_fn)

# Preprocessing the datasets.
# We need to read the audio files as arrays
def evaluate(batch):
    inputs = processor(batch["speech"], sampling_rate=16_000, return_tensors="pt", padding=True)

    with torch.no_grad():
        logits = model(inputs.input_values.to("cuda"), attention_mask=inputs.attention_mask.to("cuda")).logits

    pred_ids = torch.argmax(logits, dim=-1)
    batch["pred_strings"] = processor.batch_decode(pred_ids)
    return batch

result = test_dataset.map(evaluate, batched=True, batch_size=8)

print("WER: {:.2f}".format(100 * wer.compute(predictions=result["pred_strings"], references=result["sentence"])))
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embedding are fine-tuned or trained.
# HBox(children=(FloatProgress(value=0.0, max=1078.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=135.0), HTML(value='')))
# WER: 4.63

# %%
for entry in result:
    print('{}\t{}\n'.format(entry['sentence'], entry['pred_strings']))
# Out:
# to je tá čo robí  robotické tance tak to nie je pravda	to je tá čo robí  robotické tance tak to nie je pravda t
#
# tortúrou	tortúrou
#
# ktorá bude vyzerať takto	ktorá bude vyzerať takto
#
# a pravdepodobne tuná v našom regióne by tie dáta mm čísla vyzerali trochu odlišne	a pravdepudobne tuná v našom regióne dy tie datá  čísla vyzerali trochu odlišne
#
# bežný argument alebo bežná vec ktorú ľudia hovoria ale	bežný argument alebo bežná vec ktorú ľudia hovoria ale
#
# testovali sme to niekoľko rokov	testovali sme to niekoľko rokov
#
# a že mm ak si trúfneme byť zraniteľní  tak sme vlastne tým kým naozaj sme	a že mm ak si trúfneme byť zraniteľní  tak sme vlastne tým kým naozaj sme
#
# jeden jediný  problém  je že teda naozaj nemáme  ten dôkaz  na to že kedy môžeme byť	jeden jeniný problém je že teda naozaj nemáme ten dôkaz na to že kedy môžeme byť
#
# ale  porozumieť celému textu	ale  porozumieť celému textu
#
# my zaslúžime	my zaslúžime
#
# že v budúcnosti bude nevyhnutné aby	že v budúcnosti bude nevyhnutné aby
#
# ktorí nám	ktorý nám
#
# ale dnes už vieme na  biochemickej báze	ale dnes už vieme na  biochemickej báze
#
# navzájom interagujú tak komunikujú tak že si vymieňajú molekuly v podstate chemicky to je to čo dobre poznáme	navzájom interagujú tak komunikujú tak že si vymieňajú molekuly v podstate chemicky to je to čo dobre poznáme
#
# nejakého vektora prenášača	nejakého vektora prenášača
#
# z bratislavy do londýna	z bratislavy do londýna
#
# no a už sme nečakali  vlastne  na nejakú podporu zhora  rozhodli sme sa ako ateliér	no a už sme nečakali  vlastne na nejakú podporu zhora  rozhodli sme sa ako ateliér
#
# ktorý premieňa nejaké bezpečné liečivo na ten toxín výsledok je ten istý tá nádorová bunka	ktorý premieňa nejaké bezpečné liečivo na ten toxín výsledok je ten istý tá nádorová bunka
#
# ako omietku  vo vnútri v interiéri alebo aj v exteriéri	ako omietku  vo vnútri v interiéri alebo aj v exteriéri
#
# a až vtedy prvýkrát v indii som sa vlastne mm všetky tie otázky začal pýtať samého seba	a až vtedy prvýkrát v indii som sa vlastne m všetky tie otázky začal pýtať samého seba
#
# pohodlie únavu a  ďalšie okolnosti	pohodlie únavu a  ďalšie okolnosti pp
#
# našiel som   jedno z pravidiel podomového predajcu hovorí  že nikdy   že work	našiel som   jedno z pravidiel podomového predajcu hovorí že nikdy   že woro
#
# teda pardón  čo je to  čo je to  architektúra	teda pardón čo je to čo je to  architektúra
#
# a tisíc päťsto ťažko ranených s trvalými následkami ročne	a tisíc päťsto ťažko ranených s trvalými následkami ročne a
#
# ten album alebo to cédečko možno že to už aj pomaly končí to cédečko určite	ten album alebo to cédečko možno že to už aj pomaly končí to cédečko určite
#
# rezistentnými baktériami	rezistentnými baktériami
#
# môžete vidieť	môžete vidieť
#
# roboty zlepšovali kvalitu života autistických detí a ich rodičov alebo	roboty zlepšovali kvalitu života autistických detí a ich rodičov alebo
#
# tento účinok ktorý  sa	tento účinok ktorý  sa
#
# vytvorili tabuľku v exceli	vytvorili tabuľku v exceli
#
# v roku tisíc deväťsto deväťdesiat dva bol použitý alebo uvedený do prevádzky prvý defibrilátor pre laické použitie to znamená to je defibrilátor ktorý lieči	v roku tisíc deväťsto deväťdesiat dva bol použitý alebo uvedený do prevádzky prvý defibrilátor pre laické použitie to znamená to je defibrilátor ktorý lieči
#
# a čo tam pridávate že je to také pevné	a čo tam pridávate že je to také pevné
#
# a  vždy mm  sú tými prvými ktorí poukážu na nejaký problém a spracujú ho	a  vždy m sú tými prvými ktorí poukážu na nejaký problém a spracujú ho
#
# za päť rokov úplne jednoducho bez peňazí z  eurofondov bez nejakých miliárd  bez  bez ničoho iba my sami	za päť rokov úplne jednoducho bez peňazí s eurofondov bez nejakých miliárd  bez  bez ničoho iba my sami
#
# tisíce hviezd	tisíce hviezd
#
# predpovedať alebo  dokáz    dokázať si všimnúť na ňom	predpovedať alebo dokáz dokázať si všimnúť na ňom mr
#
# potom sedem  päťdesiat päť to už je také iné	potom sedem päťdesiat päť to už je také iné
#
# priznám sa vám že som nervózny ako keď som išiel na štátnice a tam som bol trikrát kým som ich urobil takže  uvidíme ako dopadneme	priznám sa vám že som nervózny ako keď som išiel na štátnice a tam som bol trikrát kým som ich urobil  takže  uvidíme  ako dopadneme
#
# príležitosť	príležitosť
#
# zahlcuje tie servery  tých   tých spoločností a snažili sa  znefunkčniť tieto weby	zahlcuje tie servery  tých  tých spoločností a snažili sa  znefunkčniť tieto weby
#
# mám svoje neúspechy pestujem si svoje neúspechy pretože nič vás nenaučí	mám svoje neúspechy pestujem si svoje neúspechy pretože nič vás nenaučí
#
# ako som si ich bral  možno predtým  ako som	ako som si ich bral  možno predtým  ako som k
#
# nadanie tých deciek	nadanie tých deciek
#
# ktoré začnú inderagovať	ktoré začnú inderagovať k
#
# skaut je na celý život ako skaut	skaut je na celý život ako skaut
#
# a	a
#
# uvidíme  či sa to podarí a aby som neskončil s takouto hlúposťou	uvidíme  či sa to podarí a aby som neskončil s takoutohposťou
#
# paradoxne sa s touto terapiou spája niekoľko výrazov	paradoxne sa s touto terapiou spája niekoľko výrazov
#
# a vďaka tomu  sa vlastne aj  sme sa stali akoby trochu známymi v tom leteckom svete	a vďaka tomu  sa vlastne aj sme sa stali akoby trochu známymi v tom leteckom svete
#
# som rád že som to   s vami mohol zdeliť	som rád že som to  s vami mohol zdeliť
#
# a nejako intuitívne mi to povedal  že ako asi	a nejako intuitívne mi to poedeal že ako asi
#
# strašiť ľudí  maďarskými   inváziami a podobne	strašiť ľudí  maďarskými  inváziami a podobne
#
# ale	ale
#
# tak vy všetci ste programátori	tak vy všetci ste programátori
#
# je preložený do  čínštiny pozrajú ho v tajvane v sýrii dokonca v dubaji ale nie v amerike	je príležen do činštiny  pozrejú ho vtuypanie v síry dokonca vdobají  ale nie v amerike
#
# mŕtveho mafiána ale čo vy viete možno že sa spolu dopátrame k tomu  že naozaj korupcia je	mŕtveho mafiána ale čo vy viete možno že sa spolu dopátrame k tomu že naozaj korupcia je
#
# predstavujú robota že je to niečo zlé	predstavujú robota že je to niečo zlé pp
#
# trošku taký až anekdotický	trošku taký až anekdotický
#
# o tom že či to teda je legitímna  forma umenia  sa stále diskutuje	o tom že či to teda je legitímna forma umenia sa stále diskutuje
#
# to gro ten najväčší kľúč  k zdravšiemu životu máme  vlastne  v rukách my sami týka sa	to gro ten najväčší kľúč  k zdravšiemu životu máme  vlastne v rukách my sami týka sa
#
# tím získal  hlavnú cenu a to päť miliónov	tím získal  hlavnú cenu a to päť miliónov
#
# variť	variť
#
# v tej situácii alebo inak povedané empatia	v tej situácii alebo inak povedané empatia
#
# každý rok som prešiel	každý rok som prešiel
#
# žijete desať tisíc	žijete desať tisíc
#
# a	a
#
# zo zo škôl v iných krajinách a to čo  u nás zatiaľ robia tí  devianti	zo  zo škôl v iných krajinách a to čo u nás zatiaľ robia tí  devianti
#
# ďalšia zložka čokolády sú	ďalšia zložka čokolády sú
#
# ktorý  pokojne rozmýšľa o tom	ktorý pokojne rozmýšľal o tom
#
# tak som vždy	tak som vždy
#
# toto nie sú vymyslené veci toto sú veci pozbierané zo skutočných  prípadov	toto nie sú vymyslené veci toto sú veci pozbierané zo skutočných  prípadov
#
# ďakujem  pekne	ďakujem  pekne
#
# prvá  tva  tá tvorivosť je tá najjednoduchšia proste ráno sa človek zobudí	prvá  tva  tá  tvorivosť je tá najjednoduchšia proste ráno sa človek zobudí
#
# ktorý kvôli politickým príčinám mm bol zbúraný tak  vlastne	ktorý kvôli politickým príčínam  bol zbúraný tak vlastne
#
# hlavne s  tým	hlavne s  tým
#
# my sme tvory my tvoríme	my sme tvory my tvoríme
#
# ktorý vám pomôže sa dostať z nejakého bodu a do bodu b možno rýchlejšie	ktorý vám pomôže sa dostať z nejakého bodu a do bodu b možno rýchlejšie k
#
# taký istý p    ten istý problém ale v malom čiže  taký	taký istý  p   ten istý problém ale v malom čiže taký
#
# a nemožno ho už potom meniť	a nemožno ho už potom meniť
#
# tam je to ale oveľa zložitejšie detegovať a to je jeden z našich predmetov našej výskumnej činnosti na ústave	tam je to ale oveľa zložitejšie detegovať a to je jeden z našich predmetov našej výskumnej činnosti na ústave
#
# to isté	to isté
#
# ktorá je voľne dostupná na sídlisku tu v  bratislave	ktorá je voľne dostupná na sídlisku tu v  bratislave
#
# pokojnejšej fázy ale hlavne pevného a trvácneho partnerského zväzku	pokojnejšej fázy ale hlavne pevného a trvácneho partnerského zväzku
#
# reálny   reálny  vzťah jeho s bayerom  chceme vidieť to že	reálny  reálny  vzťah jeho s bayerom  chceme vidieť to že
#
# keď môj syn  sa  dostal  do štvrtého ročníku a ja som trpel tým ako ho učia matematiku	keď môj syn  sa  dostal  do štvrtého ročníku a ja som trpel tým ako ho učia matematiku
#
# už len keď si vezmete inú uličku	o lenkesi vezmete inú uličku o
#
# a tú úlohu dávam teraz aj vám	a tú úlohu dávam teraz aj vám
#
# že či sa tá budúcnosť celkovo dá nejako predpovedať	že či sa tá budúcnosť celkovo dá nejako predpovedať
#
# ľudia dneska na sociálnych sieťach zverejňujú  o sebe principiálne čokoľvek  a tá neúcta sa vám odzrkadľuje v jednom nádhernom príklade	ľudia dneska  na sociálnych  sieťach zverejňujú  o sebe  principiálne čokoľvek  a tá neúcta sa vám modzrkadlo je v jednom nádhernom príklade
#
# pretože keď zrazu stojíte v úzadí a pozorujete ako tí susedia menia pozdrav z	pretože keď zrazu stojíte  vúzadí a pozorujete ako tí susedia menia pozdrav z
#
# a	a
#
# ja som dostal jednu  kama   esemesku od môjho nepočujúceho kamaráta	ja som dostal jednu  kama   esemesku od môjho nepočujúceho kamaráta
#
# vymyslel veľmi rafinovaný plán	vymyslel veľmi rafinovaný plán
#
# mm stáva sa otvorenejším tolerantnejším mäkším  ako to nazývam ja laicky	stáva sa otvorenejším tolerantnejším mäkším  ako to  nazývam ja laicky
#
# viacej komplexnejšie veci aby vedel chápať	viacej komplexnejšie veci aby vedel chápať
#
# ja ako pani učiteľka volím to zlé pokračovanie prečo pretože chyby sú to čo nás učí	ja ako pani učiteľka volím to zlé pokračovanie prečo pretože chyby sú to čo nás učí
#
# je možné potom žiakovi a študentovi pomôcť	je možné potom žiakovi a študentovi pomôcť
#
# a možno taký  môj odkaz všetkým  vám  je  aby  aby ste  boli aktívni	a možno taký môj odkaz všetkým  vám  je  aby  aby ste boli aktívni
#
# je tu nejaké mm ohnisko záhradka	je tu nejaké mm ohnisko záhradka
#
# neverili že ako tie dievčatá budú makať ale musím povedať že to som ešte nevidel ináč	neverili že  ako diežatá budú makať ale musím povedať  že to som ešte nevidel nináč
#
# dobré ránko toto bol teda prísľub ktorý dúfam že nesklamem	dobré ránko toto bol teda prísľub ktorý dúfam že nesklamem
#
# že nájdeme jeden spôsob ako má dobre fungovať škola	že nájdeme jeden spôsob ako má dobre fungovať škola
#
# aké asi oni majú keď prichádzajú sem	aké asi oni majú keď prichádzajú sem
#
# spoločenská konvencia	spoločenská konvencia
#
# a  niekedy sa o splodení dieťaťa dozvieme až s odstupom času	a niekedy sa o splodení dieťaťa dozvieme až s odstupom času
#
# ježišmária ja prídem o nohu	niež mari a ja prídem onohu žtžttt
#
# a bol tam zavesený taký  mobilný telefón	a bol tam zavesený taký  mobilný telefón
#
# ktorá je však pre mňa najpodstatnejšia  vždy  vždy keď som vo svojom živote počul vetu bolo by treba	ktorá je však pre mňa najpodstatnejšia  vždy  vždy keď som vo svojom živote počul vetu bolo by treba
#
# my sme tam predniesli prvýkrát aj to video ktoré teda  teraz uvidíte	my sme tam predniesli prvýkrát aj to video ktoré teda  teraz uvidíte
#
# je pravda že  ako dieťa  som chcel byť smetiar každé smetiarske auto ktoré som videl chcel som naň naskočiť chcel som tým ľuďom pomôcť	je pravda že  ako dieťa som chcel byť smetiar každej smetiarské auto ktoré som videl chcel som naň naskočiť chcel som tým ľuďom pomôcť
#
# je mm  z  mm	je m  z  m
#
# na tejto fotke to vidieť dobre že	na tejto fotke to vidieť dobre že
#
# sme mohli počuť aj ostatných	sme mohli počuť aj ostatných
#
# tak tu dnes nie ste  jednak nie ste tu	tak tu dnes nie ste  jednak nie ste tu
#
# a väčšinou je to tak že keď  my odchádzame z tohto  sveta	a väčšinou je to tak že keď  my odchádzame z tohto  sveta
#
# keď  som	keď  som
#
# pozor konfety to si všimnite	pozor konfety to si všimnite o
#
# v maličkostiach	v maličkostiach
#
# a tá transformácia z auta do lietadla trvá  zhruba dvadsať až tridsať sekúnd	a tá transformácia z auta do lietadla trvá  zhruba dvadsať až tridsať sekúnd
#
# viac ako  desaťkrát  nižšia ako u mužov	viac ako  desaťkrát  nižšia ako u mužov
#
# vytvorené emócie  alebo  alebo taká tá vytvorená realita	vytvorené emócie  alebo  alebo taká tá vytvorená realita
#
# a  v  na slovensku kde	a  v na slovensku kde
#
# trénovať icuba	trénovať icuba
#
# tode tak isto ale zaujímavé že na zemi sa nepohybujeme ako  vecs    väčšina zvierat	hode tak isto ale zaujímavé že na zemi sa nepohybujeme ako vec  väčšina zvierat
#
# takže	takže
#
# možnos mm	možnos m
#
# dúfam  že napomôže tomu troška aspoň citát  louisa	dúfam  že napomôže tomu troška aspoň citát  louisa d
#
# škrtidlo pri krvácaní na hornej končatine dávame nad ranu alebo pod ranu nad ranu	škrtidlo pri krvácaní na hornej končatine dávame nadranu alebo pod ranú nadranu
#
# na to aby ich vyriešili	na to aby ich vyriešili
#
# sa týka nás všetkých veľmi výrazne oveľa viac ako si môžeme myslieť dokonca aj mužov takže ste v tom s nami páni	sa týka nás všetkých veľmi výrazne oveľa viac ako si môžeme myslieť dokonca aj mužov takže ste v tom s nami páni
#
# vlastne zistili že to mám	vlastne zistili že to mám
#
# dobrý deň  dobrý deň	dobrý deň  dobrý deň
#
# tak mi hovorí doktorka doktorka pozri čo som nakreslila	tak mi hovorí doktorka doktorka pozri čo som nakreslila
#
# tieto jednotlivé body si viem vypočítať	tieto jednotlivé body si viem vypočítať
#
# táto  konkrétna  na obrázku je darwinova  ale mala ten problém že nebola úplne taká jednoduchá na zloženie alebo tak nejako	táto  konkrétna na obrázku je darvinova  ale mala ten problém že nebola úplne taká jednoduchá na zloženie alebo tak nejako
#
# je veľmi drahá na to aby si tí miestni ľudia  to mohli dovoliť	je veľmi drahá na to aby si tí miestno ľudia tomohli dovoliť
#
# pacienti ktorí majú problém  proste  normálne fungovať lebo stále si umývajú ruky a mm musia stále zamykať dvere a nie sú schopní	pacienti ktorí majú problém  proste normálne fungovať  lebo stále si umývajú ruky a m musia stále zamykať dvere a nie sú schopní
#
# medzinárodné výskumy a medzinárodné porovnanie	medzinárodné výskumy a medzinárodné porovnanie nn
#
# a tie vesmíry sú o dosť exotickejšie než keď mm pozeráte úchylné videoklipy z japonska alebo z ruska napríklad	a tie vesmíry sú o dosť exotickejšie než keď m pozeráte úchylné videoklypy z japonska alebo z ruska napríklad
#
# potvoríme	potvoríme
#
# a dal som si takú pracnú námahu že som z  obrázku   z pôvodného obrázku	a dal som si takú pracnú námahu že som z obrázku   z pôvodného obrázku s
#
# ktoré sa mal vytvorené	ktoré sa mal vytvorené k
#
# pardon	pardon
#
# úplne to bolo akože strašne silné pre mňa	úplne to bolo akože strašne silné pre mňa
#
# napríklad v thajsku v belgicku v usa kde som tie záchvaty zažíval	napríklad v fhajsku v belgicku v usa kde som tie záchvaty zažíval
#
# a  v  tiež je to iba sústava mm	a  v  tiež je to iba sústava mm
#
# nepočujúceho	nepočujúceho
#
# takže to druhé posolstvo je    že snažme sa nielen zdieľať informácie ale pokúsme sa ich aj kvalitne  vytvárať	takže to druhé posolstvo je  že snažme sa nielen zdieľať informácie ale pokúsme sa ich aj kvalitne  vytvárať
#
# a z rozmanitosti toho sveta	a z rozmanitosti toho sveta
#
# ktorému hrozí samozrejme vyhynutie niečo ako vták loskuták	ktorému hrozí samozrejme vyhynutie niečo ako vták loskuták
#
# ďalej pomôcť ako ďalej s tým	ďalej pomôcť ako ďalej s tým
#
# že  vlastne   v akom v akej my  v akom my žijeme chaose	že  vlastne  v akom v akej my  v akom my žijeme chaose
#
# a chcem sa preto opýtať že keď to takto nejde pri takejto jednoduchej veci ako pri voľnom čase	a chcem sa preto opýtať že keď to takto nejde pri takejto jednoduchej veci ako pri voľnom čase
#
# a tuto bol už veľmi krátky  krok k tomu	a tuto bol už veľmi krátky  krok k tomu
#
# určite zažívate alebo ste zažili aj vy	určite zažívate alebo ste zažili aj vy
#
# dospelí nie sú len silní ale sú aj zraniteľní	dospelí nie sú len silní ale sú aj zraniteľní lnlnl
#
# že aký bude výsledok tohoto problému ja si myslím že keby som vedel dejepis aj na sto percent	že aký bude výsled do k tohoto problému ja si myslím že keby som vedel depis aj násto percent a
#
# a iba  mm sedieť a rozmýšľať nad svojím životom	a iba m sedieť a rozmýšľať nad svojím životom
#
# a neurobia to za nás mm   ani  ani oni dvaja aj keď jeden z nich má naozaj veľmi pekné meno  môžte  u  hádať že ktorý	a neurobí to za n m ani  ani  oni dvaja aj keď jeden z nich má naozaj veľmi pekné meno  môžte u hádať že ktorý
#
# že  vyžije  vyriešite strašne veľa  iných vecí	že  vyžije  vyriešite strašne veľa  iných vecí
#
# pokojne už som  vlastne  dneska videl aj mm  so samotným  odpružením toho celého  kola  koliečka takže	pokojne už som  vlastne dneska videl aj m  s samotným odpružením toho celého kola koliečka takže
#
# a pomerne dobre sa dá vysvetliť to naše správanie všetci veľmi dobre viete o čom hovorím	a pomerne dobre sa dá vysvetliť to naše správanie všetci veľmi dobre viete o čom hovorím
#
# veľmi často spôsobené vylučovaním  hormónu   ktorý sa nazýva oxitocín   o tom ste už tiež určite všetci počuli	veľmi často spôsobené vylučovaním  hormónu  ktorý sa nazýva oxitocín  o tom ste už tiež určite všetci počuli
#
# zoberieme si ho do rukáva si ho schováme alebo zoberieme celú kabelku čo je oveľa nápadnejšie ale budiž	zoberieme si ho do rukáva si ho schováme alebo zoberieme celú kabelku čo je eľa nápadnejšie ale budiž
#
# prečo  vni     prečo sa nepýtame na vek dvadsať šesť ročného inžiniera	prečo vň  prečo sa nepýtame na vek dvadsať šesť ročného inžiniera
#
# realizovaný na	realizovaný na
#
# nepoviem asi ani nič nové že	nepoviem asi ani nič nové že
#
# a potom jedna úplne úchvatná a tou sú internetové mémy	a potom jedna úplne úchvatná a tou sú internetové mémy
#
# a čuduj sa svete zistil že ochota podvádzať  je ľuďom veľmi prirodzená a súvisí aj s tým aké tričko máte na sebe	a čuduj sa svete zistil že ochota podvádzať  je ľuďom veľmi prirodzená a súvisí aj s tým aké tričko máte na sebe
#
# keď si viete predstaviť najväčší lejak na  svete   tak vtedy sa to stalo	keď si viete  predstaviť najväčší  lojak na  svete  tak vtedy  sa to stalo
#
# čím robot vyzerá	čím robot vyzerá
#
# ale k tomu sa ešte dostaneme	ale k tomu sa ešte dostaneme
#
# a cítime sa zrazu veľmi veľmi príjemne	a cítime sa zrazu veľmi veľmi príjemne
#
# čo to znamená   absolútne môžete zabudnúť na riziko nejakej leukémie	čo to znamená  absolútne môžete zabudnúť na riziko nejakej leukémie o
#
# tak  som sa úplne  až  až bál niekomu niečo povedať tak hanbil	tak som sa úplne až  až bál niekomu niečo povedať tak hanbil
#
# ale   takisto aj  vlastne  v  ria  rôznych riadeniach	ale   takisto aj  vlastne  v ria  rôznych riadeniach
#
# tak	tak
#
# chodiť na nejaký kurz alebo  s  sledovať nejaké prednášky čítať knihy	chodiť na nejaký kurz alebo  s sledovať nejaké prednášky čítať knihy
#
# viac  komunikatívne niekedy chceme byť samy  so sebou	viac  komunikatívne niekedy chceme byť samy  so sebou
#
# v rámci svojich  možností   aby	v rámci svojich  možností  aby
#
# nie vždy to akceptujú alebo si povedia že na čo mi to je	nie vždy to akceptujú alebo si povedia že na čo mi to je
#
# to je dôkaz že to robili zvukári aj vtedy	to je dôkaz že to rôbici zvokári aj vtedy
#
# väčšinou sem prichádzajú s rôznymi očakávaniami	väčšinou sem prichádzajú s rôznymi očakávaniami
#
# by som  chcel	by som  chcel
#
# slováci majú radi taký čiernobiely prístup trošku že	slováci majú radi taký čiernobiely prístup trošku že
#
# a v tejto chvíli by som mohol aj skončiť	a v tejto chvíli by som mohol aj skončiť
#
# avšak	avšak
#
# takže  rada by som aj na to nadviazala  je to  je to dôležité my sme tí ktorí môžeme zažiť tú zmenu a prežiť a	takže m praca by som ajna to nadviace ale je to je to drôležité mysme ty ktorí môžeme záži ťú zmenu a prešiť a
#
# skúste ukážte  piť dobre výborne spať	skúste ukážte  piť dobre výborne spať
#
# u tej ženy to že stáva sa asertívnejšou	u tej ženy to že stáva sa asertívnejšou
#
# asi lepšie	asi lepšie
#
# má zrazu mm  úplne iný efekt zrazu počúvajú na to že keď niekto má právo na to aby	má zrazu m úplne iný efekt zrazu počúvajú na to že keď niekto má právo na to  aby pp
#
# bez toho že by sme potrebovali teraz nejaké strašne zložité procesy vymýšľať ale jednoducho  človek jednoduchšie príde na riešenie problémov	bez toho že by sme potrebovali teraz nejaké strašne zložité procesy vymýšľať ale jednoducho človek jednoduchšie príde na riešenie problémov
#
# toto je veľmi pekný príklad na ktorý sme dostali tip od  od   kamaráta a je to nákupné stredisko vo vojanoch	toto je veľmi pekný príklad na ktorý sme dostali tip od   od  kamaráta a je to nákupné stredisko vo vojanoch
#
# ja keď som  začínala  s touto témou slovenského znaku	ja keď som  začínala s touto témou slovenského znaku
#
# jednu knižku tu mám aj so sebou	jednu knižku tu mám ajsť so sebou
#
# akú šancu máme	akú šancu máme k
#
# môžem poprosiť o pomoc	môžem poprosiť o pomoc
#
# prototyp  trojku	prototyp  trojku
#
# a tak ďalej   až kým som neprišiel k týmto dverám	a tak ďalej  až kým som neprišiel k týmto dverám
#
# ale ten   najv    najvýznamnejší krok spravil  vlastne  predajca techniky keď som prišiel že chcem naozaj fotoaparát a	ale ten   najv  najvýznamnejší krok spravil  vlastne  predajca techniky keď som prišiel že chcem naozaj fotoaparát  a
#
# to je ďalšia z vecí	to je ďalšia z vecí
#
# a v podstate	a v podstate
#
# ako deti  sme sa mohli hrať iba na ihrisku	ako deti  sme sa mohli hrať iba na ihrisku
#
# práve si myslia že ešte majú ďalších tisíc životov pred sebou lebo veria v reinkarnáciu	práve si myslia že ešte majú ďalších tisíc životov pred sebou lebo veria v reinkarnáciu
#
# vytlačili už a	vytlačili už a
#
# a naozaj už sme  prešlo   viacerí ľudia zaplatili nejakou alternatívnou mincou a sme radi a podporujeme to	a naozaj už sme prešlo viacerí ľudia zaplatili nejakou alternatívnou mincou a sme radi a podporujeme to
#
# tohto  červeného tušu na plátno	tohto  červeného tušu na plátno tot
#
# cítili sa tak nejako trošku zaskočení že	cítili sa tak nejako trošku zaskočení že
#
# a ukážem vám teda že hlina má	a ukážem vám teda že hlina má
#
# ona tam zastane	ona tam zastane n
#
# ale poviem vám čo pred  tým	ale poviem vám čo pred tým
#
# sa šplhali  šplhali  na smreky a hádzali po sebe šišky že je to len taká kratochvíľa	sa šplhali šplhali na smreky a hádzali po sebe šišky že je to len taká kratochvíľa
#
# do toho integrovali dizajn   tie skúsenosti ktoré máme v spolupráci s  automobilkami sme  vlastne dali aj do tvarového riešenia	do toho integrovali dizajn  tie skúsenost ktoré máme spolupráci s automobilkami sme  vlastne dali aj do tvarového riešenia
#
# chcel to zabudovať do novej konštrukcie a je to veľmi symbolické a je to krásne	chcel to zabudovať do novej konštrukcie a je to veľmi symbolické a je to krásne
#
# to čo bolo v ulici už tam nebude a neostane po tom žiadna stopa takže  to je nejaký náš cieľ	to čo bolo v ulici už tam nebude a neostane po tom žiadna stopa takže  to je nejaký náš cieľ
#
# tak čo priatelia  poznáte svojich  susedov	tak čo priatelia  poznáte svojich  susedov
#
# uvidíte teraz a z môjho pohľadu ja som ten text nepísal	uvidíte teraz a z môjho pohľadu ja som ten text nepísal
#
# počasie vtedy nebolo úplne dobré takže  tá  účasť bola možno nejakých sto päťdesiat ľudí ale  celkom  celkom to vyšlo	po čase vtedy nebol úplne dobre takže tá účasť bola možno nejakých stopej sa ľudia le celkom celkomto vyšlo
#
# čo ďalej nám môže sa ponúknuť samozrejme špičkovú vedu a výskum pretože pravidelne prináša jedinečné vedecké objavy   ako napríklad v roku dve tisíc päť	čo ďalej nám môže sa ponúknuť samozrejme špičkovú vedu a výskum pretože pravidelne prináša jedinečné vedecké objavy  ako napríklad v roku dve tisíc päť
#
# spravené načierno nedodržovali sa predpisy	spravené načierno nedodržovali sa predpisy
#
# lenže ono to tak nefunguje takýto zázračný prútik vlastne neexistuje a	lenže ono to tak nefunguje takýto zázračný prútik vlastne neexistuje a
#
# čiže nebude už viac nebezpečný	čiže nebude už viac nebezpečný
#
# páni ktorí sa volajú poslanci a zbierajú do neho peniažky z celej krajiny od všetkých nás	páni ktorí sa volájú poslanci a zvierajú do neho peniažky zcelej krajiny od všetkých nás
#
# vlastne jednu snímku nejde o vystúpenie    rokovej ani popovej hviezdy	vlastne  jednu snímku nejde o vystúpenie  rokovej ani popovej hviezdy
#
# a ďalšia vec je že sa zaujímať o dianie ktoré sa deje  v našich lokálnych samosprávach	a ďalšia vec je že sa zaujímať o dianie ktoré sa deje  v našich lokálnych samosprávach
#
# našich  lud    ľudí  napríklad mm títo zahraniční študenti chodia do škôl	našich  lud  ľudí   napríklad mtíto zahraniční študenti chodia do škôl
#
# napríklad salmonely ktoré sa špeciálne rozmnožovali práve v tom nádore	napríklad salmonely ktoré sa špeciálne rozmnožovali práve v tom nádore
#
# vo svojej obci meste a dokonca aj v tom tradičnom priestore ktorý naša kultúra	vo svojej obci meste a dokonca aj v tom tradičnom priestore ktorý naša kultúra j
#
# sú to dve ženy je to matka s dcérou nórska umelkyňa	sú to dve ženy je to matka s dcérou nórska umelkyňa
#
# z toho sa  skladal  aj môj blog	z toho sa  skladal  aj môj blog
#
# že mi to takto nejde si to povedať deň čo deň týždeň čo týždeň alebo mesiac čo mesiac	že mi to takto nejde si to povedať deň čo deň týždeň čo týždeň alebo mesiac čo mesiac
#
# dostáva sa presne na opačnú stranu toho koňa ľudovo povedané	dostáva sa presne na opačnú stranu toho koňa ľudovo povedané
#
# akí sú v nej skvelí ľudia tak veľmi radi sa tu vracajú a každý semester keď vám odchádzajúcu  mm študenti	akí sú v nej skvelí ľudia tak veľmi radi sa tu vracajú a každý semester keď vám odchádzajú m študenti
#
# nestihneme si pozrieť tú webovú stránku vtedy keď je práve hacknutá	nestihneme si pozrieť tú webovú stránku vtedy keď je právne hacknutá
#
# prvý úspech dosiahol už v roku tisíc deväťsto osemdesiat jedna britský profesor morwen	prvý úspech dosiahol už v roku tisíc deväťsto osemdesiat jedna britský profesor morwen
#
# je to skladačka ktorá je stále rovnaká napriek tomu je stále iná	je to skladačka ktorá je stále rovnaká napriek tomu je stále iná
#
# som sa raz dočítal	som sa raz dočítal m m
#
# ste omnoho pohyblivejší	ste omnoho pohyblivejší s
#
# napríklad	napríklad
#
# a tento dôkaz sme práve našli	a tento dôkaz sme práve našli
#
# všimnite si hlavne  ten krásny  gýčový stolík s kyticou  presne tak podľa mňa znie slovo  kyberterorizmus	všimnite si hlavne  ten krásny  gýčový stolík s kyticou  presne tak podľa mňa znie slovo kyberterorizmus
#
# dajú sa aj prispôsobiť  teda   dnešnému štandardu	dajú sa aj prispôsobiť  teda  dnešnému štandardu
#
# a teraz vám niečo zahrám	a teraz vám niečo zahrám
#
# v mojom prípade	v mojom prípade
#
# pre ktorých tá matematika ozaj je zdrojom	pre ktorých tá matematika ozaj je zdrojom
#
# čo všetko som sa naučila	čo všetko som sa naučila
#
# celé to spektrum má na svojich póloch	celé to spektrum má na svojich póloch mccc
#
# venovať energiu niečomu čo	venovať energiu niečomu čo
#
# a tak ale to všetko už je dávna minulosť toto čo vidíte v tu sú  vlastne  hry	a tak ale to všetko už je dávana minulosť toto čo vidíte v tu sú  vlastne hry
#
# smrteľné poruchy srdcového rytmu rukami laika	smrteľné poruchy srdcového rytmu rukami laika
#
# tak ako bude simona krokovať  jeden dva tak my jej  tles    tľapkáme jeden dva	tak ako bude simona krokovať  jeden dva tak my jej  tles  tľapkáme jeden dva
#
# celý priestor  slovenska  je v podstate do tristo metrov voľný a môžte ho	celý priestor  slovenska  je v podstate do tristo metrov voľný a môžte ho
#
# že tvorivosť je vlastne s    vlastnosť a schopnosť ktorú máme	že tvorivosť je vlastne  s vlastnosť a schopnosť ktorú máme
#
# a preto mm prichádzame s umelou inteligencioupre takéto roboty	a preto m  prichádzame s umelou inteligenciou pre takéto roboty
#
# je to niečo s čím	je to niečo s čím
#
# takýto tanec	takýto tanec
#
# ktorý svoj boj momentálne vedie	ktorý svoj boj momentálne vedie rm
#
# a tak som si po určitej dobe uvedomila	a tak som si po určitej dobe uvedomila ll
#
# máte nejaký dýchací prístroj na chrbte automatiku	máte nejaký dýchací prístroj na chrbte automatiku
#
# a uzatvárali sa väčšmi do súkromia	a uzatvárali sa väčšmi do súkromia vrr
#
# ako  zoberme si príklad z tohto najznámejšieho  maďarského pedagóga	ako  zoberme si príklad z tohto najznámejšieho  maďarského pedagóga
#
# v tom slova  zmysme  zmysle že	v tom slova  zmysme  zmysle že
#
# budeme ti pomáhať a budeme k tebe chodiť tak dlho ako len budeš chcieť a aj potom	budeme ti pomáhať a budeme k tebe chodiť tak dlho ako len budeš chcieť a aj potom
#
# vyšetruje sa   testom  testami intuitívnej fyziky	vyšetruje sa  testom  testami intuitívnej fyziky
#
# keď budete chcieť  na    mať nejaké nápady	keď budete chcieť na   mať nejaké nápady
#
# ďakujem vám veľmi  pekne	ďakujem vám veľmi kokny
#
# a myslím že to	a myslím že to
#
# skúsim uviesť pár príkladov  takých	skúsim uviesť pár príkladov takých
#
# sme robili	sme robili
#
# kože  a sústredenie krvi v jadre  v jadre  tela	kože  a sústredenie krvi v jadre  v jadre tela
#
# a taktiež ak budete mať nejakých zahraničných priateľov tak okrem pôvodu valašky a	a taktiež ak budete mať nejakých zahraničných priateľov tak okrem pôvodu valašky a
#
# ja som hneď tam uvidel tie  architektonické  témy o tom    ako  nás  baví ten odstup  od reality a	ja som hneď tam uvidel tie  architektonické  témy o tom   ako  nás baví ten odstup  od reality a
#
# napríklad na mars je to tak	napríklad na mars je to tak
#
# a	a
#
# množstvo ľudí počujúcich ľudí  pri     pristupuje k tomu problému tak	množstvo ľudí počujúcich ľudí pri  pristupuje k tomu problému tak m
#
# búdka stojí čo je necelých šesť týždňov upozorňujem	búdka stojí čo je necelých šesť týždňov upozorňujem
#
# potom do ďalšej vrstvy zaomietali podlahové vykurovanie	potom do ďalšej vrstvy zaomietali podlahové vykurovanie
#
# tak som si povedal	tak som si povedal
#
# škola neexistuje kvôli  inému	škola neexistuje kvôli  inému
#
# taký	taký
#
# načo  je taký vysoký testosterón u chlapcov	načo  je taký vysoký testosterón u chlapcov
#
# je to commission predaj to znamená že	je to commission predaj to znamená že
#
# nádorové bunky vysielajú do svojho okolia  rôzne   signály	nádorové bunky vysielajú do svojho okolia rôzne  signály
#
# využite kvalitné využitie príležitostí	využite kvalitné využitie príležitostí
#
# môj predrečník ktorý hrá bedminton  potrebujeme  strážiť svoju váhu	môj predrečník ktorý hrá bedminton   potrebujeme  strážiť svoju váhu
#
# náš partner je polobohom	náš partner je polobohom
#
# a nemusí to byť len vaše auto	a nemusí to byť len vaše auto nnnn
#
# ktorá nikdy	ktorá nikdy
#
# penicilín ten dorazil	penicilín ten dorazil
#
# veď ich nazvi roboti	veď ich nazvi roboti
#
# a všeobecne satelitnými službami napriek kríze medziročne rastie približne o osem percent a už dnes dosahuje len v európe niekoľko desiatok miliárd eur	a všeobecne satelitnými službami napriek kríze medziročne rastie približne o osem percent a už dnes dosahuje len v európe niekoľko desiatok miliárd eur
#
# a iste to viete že  košice je od zadu	a iste to viete že  košice je od zadu
#
# ďalší prípad je napríklad  užívam si	ďalší prípad je napríklad  užívam si
#
# a svoju energiu	a svoju energiu
#
# a tak ja som odpadávala tiež  lebo teda že tak ako toto  a teda nakoniec to zlatica urobila famózne takže	a tak ja som odpadávala tiež lebo teda že  tak ako toto a teda nakoniec to zlatica urobila famózne takže
#
# tak sa práve začali diať   veci a  začalo sa  začalo sa všetko meniť k lepšiemu takže	tak sa práve začali diať   veci a  začalo sa  začalo sa všetko meniť k lepšiemu takže
#
# vlastne ako si predstavujete robota	vlastne ako si predstavujete robota
#
# už roboty nie sú limitované  v	už roboty nie sú limitované  v
#
# keď vás	keď vás
#
# to  to tak nefunguje	to to tak nefunguje
#
# ako som hovoril   veľmi dôležitý  je ten obraz v médiách	ako som hovoril  veľmi  dôležitý  je ten obraz v médiách
#
# a preto je dôležité  vedieť že sa to dá spraviť že tá skúsenosť naozaj môže byť úplne iná	a preto je dôležité vedieť že sa to dá spraviť že tá skúsenosť naozaj môže byť úplne  iná
#
# ktoré sme tiež našli	ktoré sme tiež našli
#
# mm	mm
#
# niečo o nádore ak nemáte šťastie a ste onkologický pacient	niečo o nádore ak nemáte šťastie a ste onkologický pacient
#
# aktívneho starnutia	aktívneho starnutia
#
# to sú fascinujúce čísla na tých sto gramov plastu	to sú fascinujúce čísla na tých sto gramov plastu
#
# tej lokality	tej lokality
#
# neviem či by sa v tejto miestnosti našiel aspoň jeden lebo	neviem či by sa v tejto miestnosti našiel aspoň jeden lebo
#
# v podstate momentálne tých možností nejako veľa nie je	v podstate momentálne tých možností nejako veľa nie je o
#
# že nie nie a zrazu panebože to sa nedá načítať  toto je fakt život  toto je  toto je realita toto tu je skutočné	žnie nie a zrazo povane bože to saenáva či a to je fakt život toto je toto je realita toto tu je skutočne
#
# ušetrilo by sa ročne päťdesiat jeden miliónov eur	ušetrilo by sa ročne päťdesiat jeden miliónov eur
#
# tak sme ich  pozvali  na slovensko oni s radosťou prišli	tak sme ich  pozvali  na slovensko oni s radosťou prišli
#
# ale takisto tu bude ten priestor aj pre  individuálne	ale takisto tu bude ten priestor aj pre individuálne
#
# a	a
#
# a keď to všetko spojíte a keď to všetko výjde tak je to veľmi  veľmi  príjemný zážitok	a keď to všetko spojíte a keď to všetko výjde tak je to veľmi veľmi  príjemný zážitok
#
# ale keby sme neboli kreatívni tak jednoducho nedokážeme prejsť cez prechod	ale keby sme neboli kreatívni tak jednoducho nedokážeme prejsť cez prechod
#
# a toto je obrázok ktorý sme nedávno dostali od  šesť ročnej anetky ktorá mala doma	a toto je obráz ktorý sme nedávno dostali od  šesťročnej anetky ktorá mala doma
#
# ľudia  ktorí  alebo teraz detí  keď si zoberieme také tie dievčatá v tom veku osem deväť rokov možno aj menej	ľudia  ktorí  alebo  teraz detí keď si zoberieme také tie dievčatá v tom veku osem deväť rokov možno aj menej
#
# že  čo je skutočne  čo som skutočne ja	že čo je skutočne čo som skutočne ja eee
#
# umožniť ľuďom pracovať na skrátený pracovný čas tam kde je to možné pracovať z domu	umožniť ľuďom pracovať na skrátený pracovný čas tam kde je to možné pracovať z domu
#
# že sa začali objavovať hlasy o tom  že dokážeme úplne vykoreniť odstrániť infekčné ochorenia  ako  z tohto sveta	že sa začali objavovať hlasy o tom  že dokážeme úplne vykoreniť odstrániť infekčné ochorenia ako z tohto sveta
#
# ktorými hodnotil kvalitu plátna	ktorý mi hodnotil kvalitu plátna
#
# toto nie sú boty od gucciho	toto nie sú boty od gucciho
#
# ale   priblížim čo sa nás bude týkať asi viac nie tej drahej komercie   je to že	ale priblížim čo sa nás bude týkať asi viac nie tej drahej komercie  je to že
#
# je to proste vec  ktorá je veľmi veľká a nedá sa tak ľahko predpovedať taký problém sa nedá ľahko riešiť	je to proste vec  ktorá je veľmi veľká a nedá sa tak ľahko predpovedať taký problém sa nedá ľahko riešiť
#
# či ľudia chcú počúvať takéto negatívne správy a už to stokrát počuli či by som to teda nemohlo prepojiť s tou mojou skrytou osobnosťou	či ľudia chcú počúvať takéto negatívne správy a už to stokrát počuli  či by som to teda nemohol prepojiť to mojou skrytou osobnosťou
#
# raz dva   pauza hej prinožiť  raz dva tri  tak ideme ešte raz simona	raz dva  pauza hej  prinožiť  raz dva tri  tak ideme ešte raz simona
#
# tak ja som si takéto niečo teoreticky	tak ja som si takéto niečo teoreticky
#
# hej stačí prísť dostatočne blízko k tomu človeku	hej stačí príst dostatočne blízko k tomu človeku
#
# ale	ale
#
# či muži  a ženy	či muži  a ženy
#
# jeden dva tri hej	jeden dva tri hej
#
# tak sa  potom pozriete cez  pauzu	tak sa  potom pozriete cez pauzu
#
# v industriálnej spoločnosti	v industriálnej spoločnosti
#
# a ona mi hovorí no lebo ja už k nim nepatrím	a ona mi hovorí no lebo ja už k nim nepatrím h
#
# kto z nás niekedy v živote podviedol	kto z nás niekedy v živote podviedol
#
# mm hocikto kto je nehudobník môže takto robiť hudbu môže sa tým že sa bude tešiť z toho ako veci znejú	m  hocikto kto je nehudobník môže takto robiť hudbu môže sa tým že sa bude tešiť z toho ako veci znejú
#
# plodová voda lebo to tiež nie jebez rizika	plodová voda lebo to tiež nie jebez rizika
#
# sú zdrojom nielen slabého svetla teda viditeľného žiarenia	sú zdrojom nielen slabého svetla teda viditeľného žiarenia
#
# v  pôvodne v knihe  selfish	v  pôvodne v knihe  selfish
#
# abstraktnoanglických slovíčok	abstraktnoanglických slovíčok
#
# takou symbolickou podobou znovu oživovanie	takou symbolickou podobou znovu oživovanie
#
# pästiari suroví chlapi	pästiari suroví chlapi
#
# tými verejnými kopírovacím pobočkami a týmito	tými verejnými kopírovacím pobočkami a týmito
#
# ja neviem v krčme alebo tak ak náhodou vám nič neporadia tak sa možno aspoň opijete	ja neviem v krčme alebo tak ak náhodou vám nič neporadia tak sa možno aspoň opijete
#
# to sú motýle oni sú krásne a každý z nich je iný	to sú motíle oni sú krásne a každý z nich je iný
#
# a	a
#
# a tí ma tak motivovali ísť ďalej	a tí ma tak motivovali ísť ďalej
#
# a  je to oculus	a  je to oculus
#
# ktorú	ktorú
#
# za odpadové hospodárstvo môžme  postaviť	za odpadové hospodárstvo môžme postaviť
#
# veľmi často citované výroky  a podľa mňa plne vystihuje podstatu úspechu sociálneho hackingu v internetovom svete	veľmi často citované výroky  a podľa mňa plne vystihuje podstatu úspechu sociálneho hackingu v internetovom svete
#
# ja by som tak strašne rád robil niečo vlastné	ja by som tak strašne rád robil niečo vlastné
#
# ktorá tam vznikla sme potom aplikovali naše terapeutické kmeňové bunky z tuku	ktorá tam vznikla sme potom aplikovali naše terapeutické kmeňové bunky z tuku
#
# ktorý u týchto detí nefunguje ktorý je zmutovaný	ktorý u týchto detí nefunguje ktorý je zmutovaný
#
# to čo je v mobile to čo je	to čo je v mobile to čo je
#
# panebože toto je hrozné to sa nemôže stať mne	panebože toto je hrozné to sa nemôže stať mne o
#
# a v kategórii lsa to znamená  light ktoré	a v kategórii eles sa to znamená  loicpore dicra  ktoré
#
# čo môže vyznievať trochu ako taká trošku absurdita v kontexte doby pretože čakať na	čo môže vyznievať trochu ako taká trošku absurdita v kontexte doby pretože čakať na
#
# z  zaujímavé veci sa môžu diať aj niekde kde to nevidieť niekde hlboko dole v podzemí	z zaujímavé veci sa môžu diať aj niekde kde to nevidieť niekde hlboko dole v podzemí
#
# pričom  pri pri  pri méme normálnom sa ešte dá povedať	pričom pri  pri  pri méme normálnom sa ešte dá povedať
#
# k tej podstate k tej  pravde alebo k tomu čo to ten človek mm skutočne v sebe má	k tej podstate k tej  pravde alebo k tomu čo to ten človek mm skutočne v sebe má
#
# ďalších	ďalších
#
# tu    túto službu pre mm vaše samosprávy vykonávajú	tu   túto službu pre m vaše samosprávy vykonávajú
#
# takže ako to sa  to to by  s   to by ste určite mali spraviť	takže ako to sa  to  to by   to by ste určite mali spraviť
#
# no ale	no ale
#
# toto je obrázok ktorý	toto je obrázok ktorý r
#
# no a  keď sú tí lekári úspešní a keď sú rodičia úspešní tak to dieťa sa dožije aj	no a  keď sú tí lekári úspešní a keď sú rodičia úspešní tak to dieťa sa dožije aj
#
# a  väčšinou ďalej čo môžem povedať je že  pre tú dopravu mm toho samotného predmetu bude stačiť už len ten internet keďže	a  väčšinou ďalej čo môžem povedať je že pre tú dopravu mm toho samotného predmetu bude stačiť už len ten internet keďže
#
# a tieto nádoby sú chemicky oddelené aby nedochádzalo k transportu molekúl medzi nimi aby sme vylúčili chemický kontakt	a tieto nádoby sú chemicky oddelené aby nedochádzalo k transportu molekúl medzi nimi aby sme vylúčili chemický kontakt
#
# a tento  enzým  má  pomerne jednoduchú úlohu  ale kľúčovú	a tento  enzým  má  pomerne jednoduchú úlohu  ale kľúčovú
#
# s takýmto	s takýmto
#
# a  povyv   vyvesím to na všetky brány sídliska	a povyv    vyvesymto navšetky brány sídliská
#
# a	a
#
# a túto som takto som  ja som normálne dokázal tých ľudí v tých domoch ovládať  a urobil som rekord v officee	a túto som takto  som  ja som normálne dokázal tých ľudí v tých domoch ovládať  a urobil som rekord v office
#
# a musím povedať že nakoniec sa z toho vyvinula celkom slušná taká poprocková bystrina a bol som veľmi prekvapený	a musím povedať že nakoniec sa z toho vyvinulá celkom slušná taká pob roková bistrina a bol som veľmi prekvapený
#
# trošku takými  taktiky  taktikami	trošku takými  taktiky taktikami
#
# objedná si nejakú šarmantnú modelku	objedná si nejakú šarmantnú modelku
#
# ale čo na to komercia tak    aby som  tak  zhrnul	ale čo na to komercia tak   aby som  tak  zhrnul
#
# ale takisto aj  v  v bytoch takže	ale takisto aj  v  v bytoch  takže
#
# namiesto  veľkého plátna	namiesto  veľkého plátna
#
# po prvé  v tej  v tej amerike tá operácia by veľa stála takže je to aj business case	po prvé  v tej  v tej amerike tá operácia by veľa stála takže je to aj busnes chaste
#
# rád	rád
#
# tuto bude zopár príkladov  vlastne    kde by som	tuto bude zopár príkladov  vlastne  kde by som
#
# čo je ale zaujímavé na tejto krajine je je to taký  ako  fenomén	čo je ale zaujímavé na tejto krajine je je to taký ako  fenomén
#
# dôležitá v internetovej dobe	dôležitá v internetovej dobe
#
# a takto uvažujeme my teraz v agentúre že	a takto uvažujeme my teraz v agentúre že
#
# no je dobrý na to že si môžete zahrať  hokej podľa ľadom	no je dobrý na to že si môžete zahrať  hokej podľa ľadom
#
# ale život tak nefunguje a pochopila som vďaka týmto deťom že môžme smútiť a radovať sa zároveň	ale život tak nefunguje a pochopila som vďaka týmto deťom že môžme smútiť a radovať sa zároveň
#
# pre takých  pre taký skvelý film o indii keď chcete sa mm tak viacej dozvedieť a takto vidieť že ako tam funguje tak odporúčam film	pre takých pre tký skvelý film o indii keď chcete sa  tak viacej dozvedieť a takto vidieť že ako tam funguje tak odporúčam film
#
# všetky školské systémy ktoré  vychadzujú  vykazujú výrazne lepšie výsledky ako ten  slovenský	všetky školské systémy ktoré  vychadzujú  vykazujú výrazne lepšie výsledky ako ten  slovenský
#
# a myslím že ten najlepší návrh bol  myslím s tým mlynským náhonom	a myslím že ten najlepší návrh bol  myslím s tým mlynským náhonom
#
# taký akože   taký vitálny	taký akože  taký vitálny    a
#
# bolo preto veľmi milé že prišli aj na druhý deň niektorí	bolo preto veľmi milé že prišli aj na druhý deň niektorí
#
# ja som napríklad	ja som napríklad
#
# ale aby som  ten príbeh usadil do nejakého kontextu prečo som sa rozhodol	ale aby som  ten príbeh usadil do nejakého kontextu prečo som sa rozhodol
#
# tých častí mozgu	tých častí mozgu
#
# a počas tejto mojej  vlastne  cesty	a počas tejto mojej  vlastne  cesty
#
# a	a
#
# aby sme mohli toto slabé elektromagnetické biologické žiarenie merať a vyhodnocovať	aby sme mohli toto slabé elektromagnetické biologické žiarenie merať a vyhodnocovať
#
# sa tá baktéria nerozpadáva neodovzdá genetický materiál bunke	sa tá baktéria nerozpadáva neodovzdá genetický materiál bunke
#
# a preto sa dnes  od takéhoto  od takýchto zákrokov  ustupuje a postupne   aj u nás	a preto sa dnes od takéhoto  od takýchto zákrokov  ustupuje a postupne  aj u nás a
#
# a tie ďalšie čísla sú ešte nižšie	a tie ďalšie čísla sú ešte nižšie
#
# pristupovať na zbytočné kompromisy	pristupovať na zbytočné kompromisy
#
# a mal som takú predstavu že prídem na borneo vystúpim z lietadla hneď na mňa skočí opička kusne ma had a budem v totálnej divočine  ako som si to predstavoval  od detstva	a mal som takú predstavu že prídem na borneou vystúpim z lietadla hneď na mňa skočí opička kusne ma had a budem v totálnej divočine  ak som si to predstavoval od detstva
#
# šéf firmy ktorá v tom čase vyrábala minipočítače pre vedecké účely	šéf firmy ktorá v tom čase vyrábala minipočítače pre vedecké účely
#
# ale my sa najprv musíme vysporiadať s tým že	ale my sa najprv musíme vysporiadať s tým že
#
# energiu toho mávnutia motýlieho krídla lebo aj to všetko zlé sa stane	energiu toho mávnutia motýlie hokrídla alebo aj to všetko zlé sa stane
#
# a	a
#
# no a tak sme sa rozhodli že založíme blog a skúsime pár tých článkov vyvrátiť sami jednoducho  po    postup je úplne jednoduchý vezmete článok ktorý sa vám zdá že je tam niečo chybné	no a tak sme sa rozhodli že založíme blog a skúsime pár tých článkov vyvrátiť sami jednoducho po  postup je úplne jednoduchý vezmete článok ktorý sa vám zdá že je tam niečo chybné
#
# flóru	flóru
#
# a tiež teda si uvedomujeme že naša história sa len tak búra kvôli nevedomosti	a tiež teda si uvedomujeme že naša história sa len tak búra kvôli nevedomosti
#
# skúste si zmeniť niekedy dátum svojho narodenia vo facebookovom profile	skúste si zmeniť niekedy dátum svojho narodenia vo facebookovom profile
#
# teda  nadšená  v  v matematike a na gymnáziu v prime gymnázia teda	teda  nadšená v v matematike a na gymnáziu v prime gymnázia teda
#
# ja som si ju nazval pre seba že zahoď mejkap	ja som si ju nazvoal pre seba že zahoť majkap
#
# tak ako každý nápad	tak ako každý nápad
#
# čas tej menštruácie a veľmi zjemniť krvácanie veľa žien krváca príliš veľa	čas tej menštruácie a veľmi zjemniť krvácanie veľa žien krváca príliš veľa
#
# sú zvláštne akože	sú zvláštne akože
#
# sú to deviantami oproti väčšinovému	sú to deviantami oproti väčšinovému
#
# mm	mm
#
# takže	takže
#
# pretože sa tak ľudia dohodli je to konvencia	pretože sa tak ľudia dohodli je to konvencia
#
# s priateľom lukášom  alernom  almerom a ďalšími	s priateľom  lukášom  alernom almerom a ďalšími
#
# týždeň vyzeral asi takto	týždeň vyzeral asi takto
#
# najlepšia   podľa logiky že najlepší je odpad ktorý ani nevznikne	najlepšia podľa logiky že najlepšie odpad ktorý ani nevznikne
#
# nikto nechce aby to bolo zverejnené a podobne  a keď sme sa o tom snažili si získať viac  informácií  zistili sme s kolegami že	nikto nechce aby to bolo zverejnené a podobne  a keď sme sa o tom snažili si získať viac  informácií zistili sme s kolegami že
#
# ale	ale
#
# ale na druhej strane  myslím že je potrebné aby sa riešili aj projekty ktoré sú pre	ale na druhej strane  myslím že je potrebné aby sa riešili aj projekty ktoré sú pre
#
# no a tí  poslanci  teda začali dostávať takéto sms správy	no a tí  poslanci teda začali dostávať takéto sms správy
#
# približne tak dva roky	približne tak dva roky
#
# nejakú spoločenskú dohodu dodržiavali	nejakú spoločenskú dohodu dodržiavali
#
# už aj na slovensku pribúda reštaurácií a hotelov	už aj na slovensku pribúda reštaurácií a hotelov
#
# na nejaké aktuálne udalosti	na nejaké aktuálne udalosti
#
# v čechách je  prvý stupeň päť  tried že	v čechách je  prvý stupeň päť  tried že
#
# citlivejšie rozplakalo	citlivejšie rozplakalo
#
# to znamená že	to znamená že nnnnn
#
# no raz keď sa objaví nejaký rozhovor  v komerčnom rádiu  a potom to dajú na stránku	no raz keď sa objaví nejaký rozhovor  komerčnom rádiu  a potom to dajú na stránku
#
# a	a
#
# milovaným partnerom	milovaným partnerom
#
# čo to znamená pre nás keďže vieme že sa to dá	čo to znamená pre nás keďže vieme že sa to dá
#
# ja som presvedčený že v roku dve tisíc jedna	ja som presvedčený že v roku dve tisíc jedna
#
# pošlem životopis	pošlem životopis
#
# ale  je to pre mňa výnimočná situácia hej	ale  je to pre mňa výnimočná situácia hej
#
# ako tie modré oči si pamätám dodnes	ako tie modré oči si pamätám dodnes
#
# farma	farma
#
# potom väčšinou keď   vám chýbajú  tie súčiastky tak v komunite vám ich vedia vytlačiť poslať a	potom väčšinou keď   vám chýbajú tie súčiastky tak v komunite vám ich vedia vytlačiť poslať a
#
# väčšinou sa používajú jednoduché bunkové kultúry	väčšinou sa používajú jednoduché bunkové kultúry
#
# posledná vec	posledná vec
#
# milej zuzke k meninám venuje mamka	milej zuzke k meninám venuje mamka l
#
# že ešte stále nedokážeme popísať	že ešte stále nedokážeme popísať eleen
#
# a nejaký  nejaký nejaký  význam	a nejaký  nejaký  nejaký  význam
#
# absolútne nemal kontrolu nad motorkou iba som	absolútne nemal kontrolu nad motorkou iba som últn
#
# čo je to to ale že prečo  vlastne  niekto by strašne chcel niečo robiť ale nerobí to pritom venuje sa práci ktorá ho nebaví	čo je toto ale že prečo vlastne  niekto by strašne chcel niečo robiť ale nerobí to pri tom venuje sa práci ktorá ho nebaví
#
# a  na	a  na
#
# alebo je to len môj pocit	alebo je to len môj pocit llll
#
# možno ho zažili aj vaše deti	možno ho zažili aj vaše deti
#
# v prvom rade by som chcel zdôrazniť	v prvom rade by som chcel zdôrazniť m
#
# človek by si pomyslel že teletabis tam bývajú  alebo	človek by si pomyslel že teleta by s nam bývajú  alebo
#
# takto to vyzeralo  oni   oni mali trošku iná predstavu mm	takto to vyzeralo  oni  oni mali trošku iná predstavu
#
# ...
#
# všelijaké  rady ako si napísať životopis	všelijaké  rady ako si napísať životopis
#
# kolegovia z inej neziskovky	kolegovia z inej neziskovky
#
# a že  do toho začínajú vstupovať rodičia	a že  do toho začínajú vstupovať rodičia
#
# ktoré v japonsku symbolizujú vďačnosť	ktoré v japonsku symbolizujú vďačnosť
#
# takže	takže
#
# sa integruje do dna on sa vkladá do dna tých buniek	sa integruje do dna on sa vkladá do dna tých buniek
#
# to znamená my indukujeme u  zvieratiek u myšiek u potkanov hnačky	to znamená my indukujeme u  zvieratiek u myšiek u potkanov hnačky
#
# prvý kurz prvej pomoci bol už v roku tisíc osemsto sedemdesiat osem hej čiže tie kurzy	prvý kurz prvej pomoci bol už v roku tisíc osemsto sedemdesiat osem hej čiže tie kurzy
#
# a teraz skúste	a teraz skúste
#
# ktorú si hovorím keď máme toho vyše hlavy	ktorú si hovorím keď máme toho vyše hlavy
#
# vaša milovaná zem máte ju radi a ste milovníkmi slovenska	vaša milovaná zem máte ju radi a ste milovníkmi slovenska
#
# čo môžeme robiť	čo môžeme robiť
#
# zažívali sme aj predtým ale zrazu sme mohli objavovať čo len chceme	zažívali sme aj predtým ale zrazu sme mohli objavovať čo len chceme
#
# knowhow však ostáva v danej firme  a to	knowhow však ostáva v danej firme  a to v
#
# ďakujem	ďakujem
#
# v tej  s    známej  bratislavk     bratislavskej zo šestke dávno dávno pred tým ako padol režim	v tej  s   známej  bratislavk   bratislavskej zo šestke dávno dávno pred tým ako padol režim
#
# dano teba je škoda na toto  ty  teba čakajú oveľa  lepšie  príležitosti	dano teba je škoda na toto ty teba čakajú oveľa  lepšie  príležitosti
#
# v tom čase tu slúžil lekár ktorý má dvoch synov	v tom čase tu slúžil lekár ktorý má dvoch synov
#
# mm musia sa tí dvaja stretnúť a nejakým  spôsobom  si padnúť do oka zavoňať si hneď sa k tomu  dostaneme  čo to znamená	m  musia sa tí dvaja stretnúť a nejakým spôsobom si padnúť do oka zavoňať si hneď sa k tomu dostaneme čo to znamená
#
# nemôžem tvrdiť že je to reprezentatívny prieskum ale vypovedá o realite a korešponduje s mojimi skúsenosťami	nemôžem tvrdiť že je to reprezentatívny prieskum ale vypovedá o realite a korešponduje s mojimi skúsenosťami
#
# mením stereotypy ja som bol nešťastný prvé tri týždne po návrate keď som zistil že ja  vlastne  robím to isté a stále	mením stereotypy ja som bol nešťastný prvé tri týždne po návrate keď som zistil že ja  vlastne  robím to isté a stále
#
# a ktorý galantne bozkáva ruku pani ministrovej	ktorý galantne bozkáva rukúpanímimistrovej
#
# doteraz vychádza z toho ten koncept že on stojí  v strede	doteraz vychádza z toho ten koncept že on stojí  v strede
#
# ten tretí domček vpravo to sme tam dostavali	ten  tretí domček v pravoto sme tam dostávali
#
# čo z tohto všetkého  vyplýva	čo z tohto všetkého vyplýva
#
# ja by som chcel mať syna slováka	ja by som chcel mať syna slováka
#
# v inom pohľade na vek	v inom pohľade na vek nno
#
# tam je  niekoľko  niekoľko vecí na ktoré sa tam dá pozrieť a samozrejme jedna je že od toho že naozaj si kupovať lokálne potraviny a tak do čoho nechcem úplne zachádzať	tam je  niekoľko niekoľko vecí na ktoré sa tam dá pozrieť a samozrejme jedna je že od toho že naozaj si kupovať lokálne potraviny a tak do čoho nechcem úplne zachádzať
#
# zaujímavé na ňom je že vie krásne rozprávať	zaujímavé na ňom je že vie krásne rozprávať
#
# ale ja tým že o nich už rozprávam dosť často som si povedal  že	ale ja tým že o nich už rozprávam dosť často som si povedal  že
#
# poviem vám krátky príbeh za chvíľu	poviem vám krátky príbez za chvíľu vv
#
# a ja som si uvedomil že	a ja som si uvedomil že sss
#
# dokážu vyhľadať choré poškodené miesto	dokážu vyhľadať choré poškodené miesto
#
# ale ľudia tomu venovali strašne veľa času  a je toho  strašne veľké množstvo čo znamená že my tu máme nejakú  subkultúru ktorá je nesmierne bohatá a	ale ľudia tomu venovali strašne veľa času  a je toho strašne veľké množstvo čo znamená že my tu máme nejakú subkultúru ktorá je nesmierne bohatá a
#
# mohlo by to zo mňa spraviť	mohlo by to zo mňa spraviť mll
#
# a to sa im potom zhodnotilo aj v ich práci	a to sa im potom zhodnotilo aj v ich práci a
#
# mimochodom to	mimochodom to
#
# ale má to ešte svoje tiež muchy ale  ľudské  telo zatiaľ neodmietlo napríklad to  ucho   ktoré už bolo implantované	ale má to ešte svoje tiežmuchy ale budské ťelozateľne odmietlo napríklad toucho ktoré už bolo implantovované
#
# aby sme si jednoducho vyskúšali	aby sme si jednoducho vyskúšali
#
# od iných objektov v tejto miestnosti ale	od iných objektov v tejto miestnosti ale d
#
# mali mm už trošku aj iné myšlienky  a  mm ako sú tie ktoré som uviedol ja	mal m už trošku aj iné myšlienky a m ako sú tie ktoré som uviedol  ja
#
# slovensko patrí do esa	slovensko patrí do esa
#
# ale to sú práve  tie  dôvody prečo ja fotím na film	ale to sú práve  tie  dôvody prečo ja fotím na film
#
# taktiež	taktiež
#
# o ktorých tu do detailov samozrejme hovoriť nebudem aby	o ktorých tu do detailov samozrejme hovoriť nebudem aby
#
# takže teraz je to  v   vo výbornom štádiu že vlastne sme naštartovali firmu ktorá dokončuje teraz	takže teraz je to v vo výbornom štádiu že  vlastne sme naštartovali firmu ktorá dokončuje teraz
#
# sviečky zapaľovača  zo vzdialenosti tisíc tristo kilometrov	sviečky zapaľovača  zo vzdialenosti tisíc tristo kilometrov
#
# a pekné ženy  a	a pekné ženy a
#
# ttáto sieť tento projekt sa volal arpanet   a začalo to v malom	táto sieť tento projekt sa volal arpanet  a začalo to v malom  ommo
#
# tak  určite máte niekto nejaké vlastné momenty	tak určite máte niekto nejaké vlastné momenty
#
# v búdke sa  ocitli  knihy aj z	búdke sa ocitli knihy aj z
#
# venujeme tomu aby sme skutočne len boli	venujeme tomu aby sme skutočne len boli
#
# nás môžu dokonca liečiť	nás môžu dokonca liečiť
#
# genetickej informácie bábätka	genetickej informácie bábätka
#
# profesii v športe ktorý vám zatiaľ nepoviem	profesii v športe ktorý vám zatiaľ nepoviem
#
# dostal som sa k tomu	dostal som sa k tomu
#
# čo so životom aj keď je pravda že v tom čase som nevedel celkom čo so životom	čo so životom aj keď je pravda že v tom čase som nevedel celkom čo so životom
#
# keď už sa ľudia teda nehanbia lebo tým politikom už kamaráti v krčme nenadávajú lebo do krčmy	keď už sa ľudia teda nehanbia lebo tým politikom už kamaráti v krčme nenadávajú lebo do krčmy
#
# a nedávala som vám žiadne rady pretože možno v mojich dvadsiatich droch dvoch rokoch by to vyznelo trošku smiešne že vám v niečom radím	a nedávala som vám žiadne rady pretože možno v mojich dvadsiatich droch dvoch rokoch by to vyznelo trošku smiešne že vám niečom radím
#
# a na toto všetko sú nepočujúci hrdí	a na toto všetko sú nepočujúci hrdí
#
# teraz prejdem k tým reálnym piatim cieľom alebo piatim problémom	teraz prejdem k tým reálnym piatim cieľom alebo piatim problémom  kkk
#
# ktorý ho prednesie buď to priamo do tela	ktorý ho prednesie buď to priamo do tela
#
# keď chcete počas tohto	keď chcete počas tohto
#
# klik	klik
#
# v podstate	v podstate
#
# tak nemyslím iba na nás ako na jednotlivcov na každého z nás lebo sa to týka každého z nás	tak nemyslím iba na nás ako na jednotlivcov na každého z nás lebo sa to týka každého z nás
#
# keď tie hladiny testosterónu v tom intrauterinnom živote sú najvyššie	keď tie hladiny testosterónu v tom intrauterinnom živote sú najvyššie
#
# a	a
#
# so sebou do tej výšky nesie sú to elektronické dosky	so sebou do tej výšky nesie sú to elektronické dosky
#
# je zaujímavé a naopak   veci sa dejú	je zaujímavé a naopak  veci sa dejú
#
# taktiež to uplatniť aj	taktiež to uplatniť aj
#
# a isté veci nepočujem respektíve počujem ich celkom inak ako	a isté veci nepočujem respektíve počujem ich celkom inak ako
#
# aby sme	aby sme
#
# aj v iných projektoch napríklad	aj v iných projektoch napríklad  n
#
# jazero ktoré sa nachádza pri bratislave tam známe ako štrkovka	jazero ktoré sa nachádza pri bratislave tam známe ako štrkovka
#
# v tej dobe slávili obrovský úspech	v tej dobe slávili obrovský úspech
#
# a kým	a kým
#
# vždycky to musí byť len  príťažlivé zviera	vždycky to musí byť len  príťažlivé zviera   v
#
# a	a
#
# ľudskej lásky	ľudskej lásky
#
# čím nás ten mozog odmenil za tú príjemnú aktivitu	čím nás ten mozog odmenil za tú príjemnú aktivitu
#
# akonáhle tá prvá fáza prebehla to znamená že ten prvý kontakt bol nadviazaný a všetko je v poriadku padli si do oka	akonáhle tá prvá fáza prebehla to znamená že ten prvý kontakt bol nadviazaný a všetko je v poriadku padli si do oka
#
# alebo proste niekedy nejde až tak o  tých	alebo proste niekedy nejde až tak o tých
#
# toho viac ale takisto ste sa najprv museli presekať cez  veľkú  veľké množstvo článkov ktoré mohli byť zavádzajúce alebo ktoré neboli celkom kvalitné lebo	toho viac ale takisto ste sa najprv museli presekať cez veľkú veľké množstvo článkov  ktoré mohli byť zavádzajúce alebo ktoré neboli celkom kvalitné lebo
#
# v beztiažovom stave	v beztiažovom stave
#
# a	a
#
# možno niektorí poznáte	možno niektorí poznáte
#
# na chvíľu si predstavte že sa aspoň časť z tohto podarí	na chvíľu si predstavte že sa aspoň časť z tohto podarí
#
# ale napriek tomu je to jedna z naozaj pekných ukážok	ale napriek tomu je to jedna z naozaj pekných ukážok
#
# spoločne každý z inej roly a z inej východiskovej pozície	spoločne každý z inej roly a z inej východiskovej pozície
#
# mm neskončilo to len pri prezentácii na webe ale urobili sme aj vernisáž ktorú sme situovali do priestorov tabačky	neskončilo to len pri prezentácii na webe ale urobili sme aj vernisáž ktorú sme situovali do priestorov tabačky
#
# ako spoznáme že  že   vlastne	ako spoznáme že  že  vlastne
#
# a môžme sa spýtať sami seba že či v to veríme  že či by dokázali niečo takéto spraviť	a môžme sa spýtať sami seba že či v to veríme že či by dokázali niečo takéto spraviť
#
# pretože	pretože
#
# anglickú spisovateľku ktorá bola ochotná každý	anglickú spisovateľku ktorá bola ochotná každý
#
# vám už nikdy nikto nevezme	vám už nikdy nikto nevezme
#
# a je to  tiež  celkom fyziologické	a je to  tiež  celkom fyziologické
#
# má v princípe z môjho pohľadu asi tri hlavné komponenty a to jednak audiovizuálna zložka	má v  princípe z môjho pohľadu asi tri hlavné komponenty a to jednak audiovizuálna zložka
#
# že skutočne oddelené chemicky oddelené organizmy sú schopné navzájom	čiže skutočne oddelené chemicky odeľené organizmy sú schopné navzájom č
#
# čo pre mňa je zaujímavé aby som to dopovedal je že je tu možnosť reagovať na oficiálnu  kultúru	čo pre mňa je zaujímavé aby som toto povedal je že je tu možnosť reagovať na oficiálnu kultúru
#
# ak tam nie je prítomný ypsilon chromozóm tak to bude dievčatko	ak tam nie je prítomný ypsilon chromozóm tak to bude dievčatko
#
# a ten piesok to mal celé očistiť	a ten piesok to mal celé očistiť
#
# že funguje princíp mávnutia motýlieho krídla	že funguje princíp mávnutia motýlieho krídla
#
# k tomu	k tomu
#
# lietadlo	lietadlo
#
# len pár  príklado	len pár  príklado
#
# môžeme potom v kuloároch keď mi poviete akúkoľvek chorobu ja vám poviem ako sa to dá	môžeme potom v kuloároch keď mi poviete akúkoľvek chorobu ja vám poviem ako sa to dá
#
# vytvorili sme s ňou  vlastne  inštaláciu	vytvorili sme s ňou  vlastne  inštaláciu
#
# alebo v klube lúč alebo v kine hviezda proste tuto sa to dialo hlavne ale v garážach u našich a	alebo v klube lúč alebo v kine hviezda proste tuto sa to dialo hlavne ale v garážach  u našich a
#
# a v nej je  napísané	a v nej je  napísané
#
# a	a
#
# tak povedia že naučíme vás behom jedného víkendu postaviť si tú tlačiareň	tak povedia že naučíme vás behom jedného víkendu postaviť si tú tlačiareň
#
# okoloidúca  sanitka  začala oživovanie naložila doviezla na centrálny príjem najbližšej nemocnice	okoloidúca  sanitka  začala oživovanie naložila doviezla na centrálny príjem najbližšej nemocnice
#
# kvôli úradníkom kvôli ministerstvu	kvôli úradníkom kvôli ministerstvu
#
# hudbu tú prežíva každý a každodenne a prežíva ju intenzívne	hudbu tú prežíva každý a každodenne a prežíva ju intenzívne
#
# nie sme veľmi vítanou destináciou pre migrantov	nie sme veľmi vítanou destináciou pre migrantov m
#
# dosť to aj možno počuť a  tým že mám horúčku tak  moja myseľ nepracuje tak úplne ako by mala bohužiaľ	dosť to aj možno počuť a tým že mám horúčku tak  moja myseľ nepracuje tak úplne ako by mala  bohužiaľ
#
# a samozrejme deti potrebujú  zrie  zdieľať aj radosť potrebujú s nami blbnúť hrať sa	a samozrejme deti potrebujú z rieh zdieľadej radosť potrebujú sa nami bobnúť hradca
#
# vidíte rôznych robotov	vidíte rôznych robotov
#
# nepríjemné a strastiplné	nepríjemné a strastiplné
#
# ale umelá  inteligencia  nie sú iba roboty	ale umelá  inteligencia  nie sú iba roboty l
#
# no	no
#
# potom  vlastne    bolo   je jej výhodou že bola cenovo dostupná dala sa zložiť okolo šesťsto dolárov   pár rokov ešte dozadu	potom  vlastne  bolo  ale jej výhodou že bola cenovo dostupná dala sa zložiť okolo šesťsto dolárov   pár rokov ešte dozadu
#
# naša a  naš  mm  naše jedlá naša príroda naša vôňa	naša a  naš naše jedlá naša príroda naša vôňa
#
# a   v množstve prípadov tá láska po istnom čase končí dochádza k rozchodu čo je veľmi nemilá záležitosť	a  v množstvoje prípadov tá láska po istom čase končí dochádza k rozchoduče veľmi nemilá záležitosť
#
# prenikavý úspech ampicilínu	prenikavý úspech ampicilínu
#
# sa nachádza v stave kedy sa informačné technológie nachádzajú v roku dve tisíc päť	sa nachádza v stave kedy sa informačné technológie nachádzajú v roku dve tisíc päť
#
# potom sme si nechali doma nabíjačky na mobil takže sme nemali ani mobil	potom sme si nechali doma nabíjačky na mobil takže sme nemali ani mobil
#
# tomuto pánovi stewart sa volá	tomuto pánovi stewart sa volá
#
# ďalej že sú naši starší ľudia menej  prítomní   vo verejnom priestore	ďalej že sú naši starší ľudia menej  prítomní  vo verejnom priestore
#
# volá sa to cathode  amusement niečo ako crt zábavné zariadenie	volá sa to cathoda  ameusemant niečo ako crt zábavné zariadenie
#
# dano ja som nevedel že ja takto dokážem rozmýšľať že	dano ja som nevedel že ja takto dokážem rozmýšľať že
#
# od	od
#
# nejaká	nejaká
#
# potom  dielo nie je duševným vlastníctvom má kolektívny charakter a narába sa s ním voľne	potom dielo nie je duševným vlastníctvom má kolektívny charakter a narába sa s ním voľne
#
# dnes pribúdajú na slovensku chválabohu firmy ktoré začínajú motivovať svojich zamestnancov k tomu aby robili niečo dobrovoľnícke	dnes pribúdajú na slovensku chválabohu firmy ktoré začínajú motivovať svojich zamestnancov k tomu aby robili niečo dobrovoľnícke
#
# alebo   obuč  obujte si dve rôzne ponožky len tak sami pre seba	alebo   obuč  obujte si dve rôzne ponožky len tak sami pre seba
#
# takže ja som pani učiteľka	takže ja som pani učiteľka
#
# a   táto bariéra ktorá sprevádza život nepočujúcich každý deň	a  táto bariéra ktorá sprevádza život nepočujúcich každý deň
#
# k online grafity alebo ku grafity	k online grafity alebo ku grafity
#
# spýtali sme sa ich ako by hodnotili úroveň znalosti v  problematike  rizík u žiakov pedagógov a u rodičov	spýtali sme sa ich ako by hodnotili úroveň znalosti v problematike  rizík u žiakov pedagógov a u rodičov
#
# vlastne o slovensku a že prečo tu žiť a odísť preč alebo radšej vôbec nie a tak a	vlastne o slovensku a že prečo tu žiť a odísť preč alebo radšej vôbec nie a tak a
#
# niekedy	niekedy
#
# na éru ešte osembitových počítačov	na éru ešte osembitových počítačov
#
# z  tak či tak musím povedať poedať že vždy keď	z  tak či tak musím povedať podať že vdy keď
#
# je empatia alebo schopnosť empatie	je empatia alebo schopnosť empatie
#
# ale aj elektromagnetického žiarenia v iných spektrálnych oblastiach	ale aj elektromagnetického žiarenia v iných spektrálnych oblastiach
#
# uvedomil som si že ako keby  všetci tí	uvedomil som si že ako keby  všetci tí
#
# prírodu v okolí	prírodu v okolí
#
# textil papier potraviny mlieko	textil papier potraviny mlieko
#
# ako na nás povedzme vplýva reklama a ako	ako na nás povedzme vplýva reklama a ako
#
# pokúšal som sa napríklad vypočítať že koľko kociek ľadu musíte dať do pohára v takom letnom dni na to aby ste si ho príjemne  znate  z dvadsiatich stupňov ochladili	pokúšal som sa napríklad vypočítať že koľko kociek ľadu musíte dať do pohára v takom letnom dni na to aby ste si ho príjemne z zate  dvadsiatich stupňov ochladili

# %% [markdown]
# The training loss goes down and we can see that the WER on the test set also improves nicely. Because this notebook is just for demonstration purposes, we can stop here.
#
# The resulting model of this notebook has been saved to [`patrickvonplaten/wav2vec2-large-xlsr-turkish-demo`](https://huggingface.co/patrickvonplaten/wav2vec2-large-xlsr-turkish-demo)
#
# As a final check, let's load the model and verify that it indeed has learned to transcribe Turkish speech.
#
# Let's first load the pretrained checkpoint.

# %%
model = Wav2Vec2ForCTC.from_pretrained(pretrain_model).to("cuda")
processor = Wav2Vec2Processor.from_pretrained(pretrain_model)

# %% [markdown]
# Now, we will just take the first example of the test set, run it through the model and take the `argmax(...)` of the logits to retrieve the predicted token ids.

# %%
input_dict = processor(tedxsk_test["input_values"][0], return_tensors="pt", padding=True)

logits = model(input_dict.input_values.to("cuda")).logits

pred_ids = torch.argmax(logits, dim=-1)[0]

# %% [markdown]
# We adapted `common_voice_test` quite a bit so that the dataset instance does not contain the original sentence label anymore. Thus, we re-use the original dataset to get the label of the first example.

# %%
common_voice_test_transcription = load_dataset("common_voice", language_code, data_dir=data_dir, split="test")

# %% [markdown]
# Finally, we can decode the example.

# %%
print("Prediction:")
print(processor.decode(pred_ids))

print("\nReference:")
print(common_voice_test_transcription["sentence"][0].lower())

# %% [markdown]
# Alright! The transcription can definitely be recognized from our prediction, but it is far from being perfect. Training the model a bit longer, spending more time on the data preprocessing, and especially using a language model for decoding would certainly improve the model's overall performance.
#
# For a demonstration model on a low-resource language, the results are acceptable, however 🤗.
