# %%
import requests 
from bs4 import BeautifulSoup

# %%
URL='http://www.miesiecznikpomerania.pl/audio'

# %%
req = requests.get(URL)
soup = BeautifulSoup(req.content, 'html.parser')

# %%
contents = list()
for part in soup.find_all('div', class_='sp-accordion-inner'):
  out = {}
  audtag = part.find('audio')
  source = audtag.find('source')
  out['audio'] = 'http://www.miesiecznikpomerania.pl{}'.format(source['src'])
  audtag.decompose()
  out['text'] = part.text.strip()
  contents.append(out)

# %%
for c in contents:
  # !echo http://web.archive.org/web/{c['audio']} >> input

# %%
# !cat input|sort|uniq > input.s
# !wget -i input.s

# %%
import json
with open('data.json', 'w') as outfile:
    json.dump(contents, outfile)

# %%
# !for i in *.ogg;do ffmpeg -i "$i" -acodec pcm_s16le -ac 1 -ar 16000 "$i.wav";done
# Out:
# ffmpeg version 4.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/opt/conda --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1566210161358/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, ogg, from '20.Tatiana Slowi - Stoleca godo po kaszebsku.ogg':
#   Duration: 00:03:15.82, start: 0.043537, bitrate: 214 kb/s
#     Stream #0:0: Audio: vorbis, 44100 Hz, stereo, fltp, 240 kb/s
#     Metadata:
#       genre           : Other
#       encoder         : Lavf52.94.0
# Stream mapping:
#   Stream #0:0 -> #0:0 (vorbis (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to '20.Tatiana Slowi - Stoleca godo po kaszebsku.ogg.wav':
#   Metadata:
#     ISFT            : Lavf58.29.100
#     Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 16000 Hz, mono, s16, 256 kb/s
#     Metadata:
#       genre           : Other
#       encoder         : Lavc58.54.100 pcm_s16le
# [wav @ 0x556491932200] Non-monotonous DTS in output stream 0:0; previous: 62097, current: 61957; changing to 62097. This may result in incorrect timestamps in the output file.
# [wav @ 0x556491932200] Non-monotonous DTS in output stream 0:0; previous: 62097, current: 62004; changing to 62097. This may result in incorrect timestamps in the output file.
# [wav @ 0x556491932200] Non-monotonous DTS in output stream 0:0; previous: 62097, current: 62050; changing to 62097. This may result in incorrect timestamps in the output file.
# [wav @ 0x556491932200] Non-monotonous DTS in output stream 0:0; previous: 240380, current: 240287; changing to 240380. This may result in incorrect timestamps in the output file.
# [wav @ 0x556491932200] Non-monotonous DTS in output stream 0:0; previous: 286402, current: 286263; changing to 286402. This may result in incorrect timestamps in the output file.
# [wav @ 0x556491932200] Non-monotonous DTS in output stream 0:0; previous: 286402, current: 286309; changing to 286402. This may result in incorrect timestamps in the output file.
# [wav @ 0x556491932200] Non-monotonous DTS in output stream 0:0; previous: 286402, current: 286356; changing to 286402. This may result in incorrect timestamps in the output file.
# [wav @ 0x556491932200] Non-monotonous DTS in output stream 0:0; previous: 389127, current: 389011; changing to 389127. This may result in incorrect timestamps in the output file.
# [wav @ 0x556491932200] Non-monotonous DTS in output stream 0:0; previous: 436867, current: 436821; changing to 436867. This may result in incorrect timestamps in the output file.
# [wav @ 0x556491932200] Non-monotonous DTS in output stream 0:0; previous: 495706, current: 495521; changing to 495706. This may result in incorrect timestamps in the output file.
# [wav @ 0x556491932200] Non-monotonous DTS in output stream 0:0; previous: 604562, current: 604539; changing to 604562. This may result in incorrect timestamps in the output file.
# [wav @ 0x556491932200] Non-monotonous DTS in output stream 0:0; previous: 645614, current: 645568; changing to 645614. This may result in incorrect timestamps in the output file.
# [wav @ 0x556491932200] Non-monotonous DTS in output stream 0:0; previous: 665792, current: 665677; changing to 665792. This may result in incorrect timestamps in the output file.
# [wav @ 0x556491932200] Non-monotonous DTS in output stream 0:0; previous: 665792, current: 665723; changing to 665792. This may result in incorrect timestamps in the output file.
# [wav @ 0x556491932200] Non-monotonous DTS in output stream 0:0; previous: 665792, current: 665770; changing to 665792. This may result in incorrect timestamps in the output file.
# [wav @ 0x556491932200] Non-monotonous DTS in output stream 0:0; previous: 716203, current: 716110; changing to 716203. This may result in incorrect timestamps in the output file.
# [wav @ 0x556491932200] Non-monotonous DTS in output stream 0:0; previous: 716203, current: 716157; changing to 716203. This may result in incorrect timestamps in the output file.
# [wav @ 0x556491932200] Non-monotonous DTS in output stream 0:0; previous: 756977, current: 756769; changing to 756977. This may result in incorrect timestamps in the output file.
# [wav @ 0x556491932200] Non-monotonous DTS in output stream 0:0; previous: 797798, current: 797775; changing to 797798. This may result in incorrect timestamps in the output file.
# [wav @ 0x556491932200] Non-monotonous DTS in output stream 0:0; previous: 864068, current: 863929; changing to 864068. This may result in incorrect timestamps in the output file.
# [wav @ 0x556491932200] Non-monotonous DTS in output stream 0:0; previous: 884247, current: 884223; changing to 884247. This may result in incorrect timestamps in the output file.
# [wav @ 0x556491932200] Non-monotonous DTS in output stream 0:0; previous: 1048481, current: 1048434; changing to 1048481. This may result in incorrect timestamps in the output file.
# [wav @ 0x556491932200] Non-monotonous DTS in output stream 0:0; previous: 1094549, current: 1094456; changing to 1094549. This may result in incorrect timestamps in the output file.
# [wav @ 0x556491932200] Non-monotonous DTS in output stream 0:0; previous: 1094549, current: 1094503; changing to 1094549. This may result in incorrect timestamps in the output file.
# [wav @ 0x556491932200] Non-monotonous DTS in output stream 0:0; previous: 1201964, current: 1201826; changing to 1201964. This may result in incorrect timestamps in the output file.
# [wav @ 0x556491932200] Non-monotonous DTS in output stream 0:0; previous: 1228366, current: 1228343; changing to 1228366. This may result in incorrect timestamps in the output file.
# [wav @ 0x556491932200] Non-monotonous DTS in output stream 0:0; previous: 1295077, current: 1295054; changing to 1295077. This may result in incorrect timestamps in the output file.
# [wav @ 0x556491932200] Non-monotonous DTS in output stream 0:0; previous: 1381966, current: 1381780; changing to 1381966. This may result in incorrect timestamps in the output file.
# [wav @ 0x556491932200] Non-monotonous DTS in output stream 0:0; previous: 1381966, current: 1381826; changing to 1381966. This may result in incorrect timestamps in the output file.
# [wav @ 0x556491932200] Non-monotonous DTS in output stream 0:0; previous: 1381966, current: 1381873; changing to 1381966. This may result in incorrect timestamps in the output file.
# [wav @ 0x556491932200] Non-monotonous DTS in output stream 0:0; previous: 1381966, current: 1381919; changing to 1381966. This may result in incorrect timestamps in the output file.
# [wav @ 0x556491932200] Non-monotonous DTS in output stream 0:0; previous: 1461192, current: 1461006; changing to 1461192. This may result in incorrect timestamps in the output file.
# [wav @ 0x556491932200] Non-monotonous DTS in output stream 0:0; previous: 1524489, current: 1524351; changing to 1524489. This may result in incorrect timestamps in the output file.
# [wav @ 0x556491932200] Non-monotonous DTS in output stream 0:0; previous: 1585558, current: 1585372; changing to 1585558. This may result in incorrect timestamps in the output file.
# [wav @ 0x556491932200] Non-monotonous DTS in output stream 0:0; previous: 1678624, current: 1678601; changing to 1678624. This may result in incorrect timestamps in the output file.
# [wav @ 0x556491932200] Non-monotonous DTS in output stream 0:0; previous: 1763237, current: 1763075; changing to 1763237. This may result in incorrect timestamps in the output file.
# [wav @ 0x556491932200] Non-monotonous DTS in output stream 0:0; previous: 1979554, current: 1979392; changing to 1979554. This may result in incorrect timestamps in the output file.
# [wav @ 0x556491932200] Non-monotonous DTS in output stream 0:0; previous: 2031451, current: 2031335; changing to 2031451. This may result in incorrect timestamps in the output file.
# [wav @ 0x556491932200] Non-monotonous DTS in output stream 0:0; previous: 2031451, current: 2031381; changing to 2031451. This may result in incorrect timestamps in the output file.
# [wav @ 0x556491932200] Non-monotonous DTS in output stream 0:0; previous: 2031451, current: 2031428; changing to 2031451. This may result in incorrect timestamps in the output file.
# [wav @ 0x556491932200] Non-monotonous DTS in output stream 0:0; previous: 2050050, current: 2049958; changing to 2050050. This may result in incorrect timestamps in the output file.
# [wav @ 0x556491932200] Non-monotonous DTS in output stream 0:0; previous: 2050050, current: 2050004; changing to 2050050. This may result in incorrect timestamps in the output file.
# [wav @ 0x556491932200] Non-monotonous DTS in output stream 0:0; previous: 2183217, current: 2183077; changing to 2183217. This may result in incorrect timestamps in the output file.
# [wav @ 0x556491932200] Non-monotonous DTS in output stream 0:0; previous: 2183217, current: 2183124; changing to 2183217. This may result in incorrect timestamps in the output file.
# [wav @ 0x556491932200] Non-monotonous DTS in output stream 0:0; previous: 2183217, current: 2183170; changing to 2183217. This may result in incorrect timestamps in the output file.
# [wav @ 0x556491932200] Non-monotonous DTS in output stream 0:0; previous:
native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to '28. Szkolna bec.ogg.wav':
#   Metadata:
#     ISFT            : Lavf58.29.100
#     Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 16000 Hz, mono, s16, 256 kb/s
#     Metadata:
#       genre           : Other
#       encoder         : Lavc58.54.100 pcm_s16le
# [wav @ 0x55de01784d00] Non-monotonous DTS in output stream 0:0; previous: 70364, current: 70178; changing to 70364. This may result in incorrect timestamps in the output file.
# [wav @ 0x55de01784d00] Non-monotonous DTS in output stream 0:0; previous: 125209, current: 125046; changing to 125209. This may result in incorrect timestamps in the output file.
# [wav @ 0x55de01784d00] Non-monotonous DTS in output stream 0:0; previous: 209381, current: 209172; changing to 209381. This may result in incorrect timestamps in the output file.
# ...
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, ogg, from '62_Eugeniusz_Pryczkowski_-_Wjedno_kaszebe.ogg':
#   Duration: 00:09:39.41, start: 0.000000, bitrate: 97 kb/s
#     Stream #0:0: Audio: vorbis, 44100 Hz, mono, fltp, 96 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (vorbis (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to '62_Eugeniusz_Pryczkowski_-_Wjedno_kaszebe.ogg.wav':
#   Metadata:
#     ISFT            : Lavf58.29.100
#     Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 16000 Hz, mono, s16, 256 kb/s
#     Metadata:
#       encoder         : Lavc58.54.100 pcm_s16le
# size=   18107kB time=00:09:39.42 bitrate= 256.0kbits/s speed= 516x
# video:0kB audio:18107kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.000421%
# ffmpeg version 4.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/opt/conda --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1566210161358/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, ogg, from '64_Kazimierz_Ostrowski_-_Janio_Chemwsczg.ogg':
#   Duration: 00:04:11.35, start: 0.000000, bitrate: 96 kb/s
#     Stream #0:0: Audio: vorbis, 44100 Hz, mono, fltp, 96 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (vorbis (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to '64_Kazimierz_Ostrowski_-_Janio_Chemwsczg.ogg.wav':
#   Metadata:
#     ISFT            : Lavf58.29.100
#     Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 16000 Hz, mono, s16, 256 kb/s
#     Metadata:
#       encoder         : Lavc58.54.100 pcm_s16le
# size=    7855kB time=00:04:11.36 bitrate= 256.0kbits/s speed= 382x
# video:0kB audio:7855kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.000970%
# ffmpeg version 4.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/opt/conda --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1566210161358/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, ogg, from '65_Lucyna_Kurpiewska_-_Kaszbsczi_krl_miodnosc.ogg':
#   Duration: 00:09:01.14, start: 0.000000, bitrate: 96 kb/s
#     Stream #0:0: Audio: vorbis, 44100 Hz, mono, fltp, 96 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (vorbis (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to '65_Lucyna_Kurpiewska_-_Kaszbsczi_krl_miodnosc.ogg.wav':
#   Metadata:
#     ISFT            : Lavf58.29.100
#     Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 16000 Hz, mono, s16, 256 kb/s
#     Metadata:
#       encoder         : Lavc58.54.100 pcm_s16le
# size=   16911kB time=00:09:01.14 bitrate= 256.0kbits/s speed= 543x
# video:0kB audio:16911kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.000450%
# ffmpeg version 4.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/opt/conda --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1566210161358/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, ogg, from '66_Egeniusz_Prczkwsczi_-_Stegn_smierc_kl_Brazylii.ogg':
#   Duration: 00:11:19.51, start: 0.000000, bitrate: 96 kb/s
#     Stream #0:0: Audio: vorbis, 44100 Hz, mono, fltp, 96 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (vorbis (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to '66_Egeniusz_Prczkwsczi_-_Stegn_smierc_kl_Brazylii.ogg.wav':
#   Metadata:
#     ISFT            : Lavf58.29.100
#     Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 16000 Hz, mono, s16, 256 kb/s
#     Metadata:
#       encoder         : Lavc58.54.100 pcm_s16le
# size=   21235kB time=00:11:19.53 bitrate= 256.0kbits/s speed= 507x
# video:0kB audio:21235kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.000359%
# ffmpeg version 4.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/opt/conda --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1566210161358/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, ogg, from '68_Rmk_Drzdnk_-_W_szkoowi_awie.ogg':
#   Duration: 00:04:50.41, start: 0.000000, bitrate: 96 kb/s
#     Stream #0:0: Audio: vorbis, 44100 Hz, mono, fltp, 96 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (vorbis (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to '68_Rmk_Drzdnk_-_W_szkoowi_awie.ogg.wav':
#   Metadata:
#     ISFT            : Lavf58.29.100
#     Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 16000 Hz, mono, s16, 256 kb/s
#     Metadata:
#       encoder         : Lavc58.54.100 pcm_s16le
# size=    9076kB time=00:04:50.42 bitrate= 256.0kbits/s speed= 368x
# video:0kB audio:9076kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.000839%
# ffmpeg version 4.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/opt/conda --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1566210161358/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, ogg, from '69_Martina_Zienkiewicz_-_Zrzeszony_z_regiona.ogg':
#   Duration: 00:03:44.24, start: 0.000000, bitrate: 96 kb/s
#     Stream #0:0: Audio: vorbis, 44100 Hz, mono, fltp, 96 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (vorbis (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to '69_Martina_Zienkiewicz_-_Zrzeszony_z_regiona.ogg.wav':
#   Metadata:
#     ISFT            : Lavf58.29.100
#     Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 16000 Hz, mono, s16, 256 kb/s
#     Metadata:
#       encoder         : Lavc58.54.100 pcm_s16le
# size=    7008kB time=00:03:44.24 bitrate= 256.0kbits/s speed= 363x
# video:0kB audio:7008kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.001087%
# ffmpeg version 4.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/opt/conda --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1566210161358/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, ogg, from '70_Maya_Gielniak_-_Godka_o_kaszebsczich_kowbojach.ogg':
#   Duration: 00:09:31.63, start: 0.000000, bitrate: 96 kb/s
#     Stream #0:0: Audio: vorbis, 44100 Hz, mono, fltp, 96 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (vorbis (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to '70_Maya_Gielniak_-_Godka_o_kaszebsczich_kowbojach.ogg.wav':
#   Metadata:
#     ISFT            : Lavf58.29.100
#     Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 16000 Hz, mono, s16, 256 kb/s
#     Metadata:
#       encoder         : Lavc58.54.100 pcm_s16le
# size=   17864kB time=00:09:31.64 bitrate= 256.0kbits/s speed= 462x
# video:0kB audio:17864kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.000426%
# ffmpeg version 4.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/opt/conda --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1566210161358/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, ogg, from '74_Romk_Drzezdzonk_-_Jesenne_godczi_o_pelckowsczi_pismieniznie.ogg':
#   Duration: 00:03:58.17, start: 0.000000, bitrate: 96 kb/s
#     Stream #0:0: Audio: vorbis, 44100 Hz, mono, fltp, 96 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (vorbis (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to '74_Romk_Drzezdzonk_-_Jesenne_godczi_o_pelckowsczi_pismieniznie.ogg.wav':
#   Metadata:
#     ISFT            : Lavf58.29.100
#     Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 16000 Hz, mono, s16, 256 kb/s
#     Metadata:
#       encoder         : Lavc58.54.100 pcm_s16le
# size=    7443kB time=00:03:58.18 bitrate= 256.0kbits/s speed= 354x
# video:0kB audio:7443kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.001023%
# ffmpeg version 4.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/opt/conda --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1566210161358/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, ogg, from '75_Pioter_Dzekanowsczi_-_Nazod_do_lasu.ogg':
#   Duration: 00:05:15.29, start: 0.000000, bitrate: 96 kb/s
#     Stream #0:0: Audio: vorbis, 44100 Hz, mono, fltp, 96 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (vorbis (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to '75_Pioter_Dzekanowsczi_-_Nazod_do_lasu.ogg.wav':
#   Metadata:
#     ISFT            : Lavf58.29.100
#     Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 16000 Hz, mono, s16, 256 kb/s
#     Metadata:
#       encoder         : Lavc58.54.100 pcm_s16le
# size=    9853kB time=00:05:15.30 bitrate= 256.0kbits/s speed= 388x
# video:0kB audio:9853kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.000773%
# ffmpeg version 4.2 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 7.3.0 (crosstool-NG 1.23.0.449-a04d0)
#   configuration: --prefix=/opt/conda --cc=/home/conda/feedstock_root/build_artifacts/ffmpeg_1566210161358/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --disable-openssl --enable-avresample --enable-gnutls --enable-gpl --enable-hardcoded-tables --enable-libfreetype --enable-libopenh264 --enable-libx264 --enable-pic --enable-pthreads --enable-shared --enable-static --enable-version3 --enable-zlib --enable-libmp3lame
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, ogg, from '76_Ewelina_Roman_Drzezdzonowie_-_Zamarte.ogg':
#   Duration: 00:06:55.52, start: 0.000000, bitrate: 96 kb/s
#     Stream #0:0: Audio: vorbis, 44100 Hz, mono, fltp, 96 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (vorbis (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to '76_Ewelina_Roman_Drzezdzonowie_-_Zamarte.ogg.wav':
#   Metadata:
#     ISFT            : Lavf58.29.100
#     Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 16000 Hz, mono, s16, 256 kb/s
#     Metadata:
#       encoder         : Lavc58.54.100 pcm_s16le
# size=   12986kB time=00:06:55.54 bitrate= 256.0kbits/s speed= 536x
# video:0kB audio:12986kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.000587%

# %%
# !pip install librosa webrtcvad
"""
Created on Tue Dec 18 16:22:41 2018

@author: Harry
Modified from https://github.com/wiseman/py-webrtcvad/blob/master/example.py
"""

import collections
import contextlib
import numpy as np
import sys
import librosa
import wave

import webrtcvad

#from hparam import hparam as hp
sr = 16000

def read_wave(path, sr):
    """Reads a .wav file.
    Takes the path, and returns (PCM audio data, sample rate).
    Assumes sample width == 2
    """
    with contextlib.closing(wave.open(path, 'rb')) as wf:
        num_channels = wf.getnchannels()
        assert num_channels == 1
        sample_width = wf.getsampwidth()
        assert sample_width == 2
        sample_rate = wf.getframerate()
        assert sample_rate in (8000, 16000, 32000, 48000)
        pcm_data = wf.readframes(wf.getnframes())
    data, _ = librosa.load(path, sr)
    assert len(data.shape) == 1
    assert sr in (8000, 16000, 32000, 48000)
    return data, pcm_data
    
class Frame(object):
    """Represents a "frame" of audio data."""
    def __init__(self, bytes, timestamp, duration):
        self.bytes = bytes
        self.timestamp = timestamp
        self.duration = duration


def frame_generator(frame_duration_ms, audio, sample_rate):
    """Generates audio frames from PCM audio data.
    Takes the desired frame duration in milliseconds, the PCM data, and
    the sample rate.
    Yields Frames of the requested duration.
    """
    n = int(sample_rate * (frame_duration_ms / 1000.0) * 2)
    offset = 0
    timestamp = 0.0
    duration = (float(n) / sample_rate) / 2.0
    while offset + n < len(audio):
        yield Frame(audio[offset:offset + n], timestamp, duration)
        timestamp += duration
        offset += n


def vad_collector(sample_rate, frame_duration_ms,
                  padding_duration_ms, vad, frames):
    """Filters out non-voiced audio frames.
    Given a webrtcvad.Vad and a source of audio frames, yields only
    the voiced audio.
    Uses a padded, sliding window algorithm over the audio frames.
    When more than 90% of the frames in the window are voiced (as
    reported by the VAD), the collector triggers and begins yielding
    audio frames. Then the collector waits until 90% of the frames in
    the window are unvoiced to detrigger.
    The window is padded at the front and back to provide a small
    amount of silence or the beginnings/endings of speech around the
    voiced frames.
    Arguments:
    sample_rate - The audio sample rate, in Hz.
    frame_duration_ms - The frame duration in milliseconds.
    padding_duration_ms - The amount to pad the window, in milliseconds.
    vad - An instance of webrtcvad.Vad.
    frames - a source of audio frames (sequence or generator).
    Returns: A generator that yields PCM audio data.
    """
    num_padding_frames = int(padding_duration_ms / frame_duration_ms)
    # We use a deque for our sliding window/ring buffer.
    ring_buffer = collections.deque(maxlen=num_padding_frames)
    # We have two states: TRIGGERED and NOTTRIGGERED. We start in the
    # NOTTRIGGERED state.
    triggered = False

    voiced_frames = []
    for frame in frames:
        is_speech = vad.is_speech(frame.bytes, sample_rate)

        if not triggered:
            ring_buffer.append((frame, is_speech))
            num_voiced = len([f for f, speech in ring_buffer if speech])
            # If we're NOTTRIGGERED and more than 90% of the frames in
            # the ring buffer are voiced frames, then enter the
            # TRIGGERED state.
            if num_voiced > 0.9 * ring_buffer.maxlen:
                triggered = True
                start = ring_buffer[0][0].timestamp
                # We want to yield all the audio we see from now until
                # we are NOTTRIGGERED, but we have to start with the
                # audio that's already in the ring buffer.
                for f, s in ring_buffer:
                    voiced_frames.append(f)
                ring_buffer.clear()
        else:
            # We're in the TRIGGERED state, so collect the audio data
            # and add it to the ring buffer.
            voiced_frames.append(frame)
            ring_buffer.append((frame, is_speech))
            num_unvoiced = len([f for f, speech in ring_buffer if not speech])
            # If more than 90% of the frames in the ring buffer are
            # unvoiced, then enter NOTTRIGGERED and yield whatever
            # audio we've collected.
            if num_unvoiced > 0.9 * ring_buffer.maxlen:
                triggered = False
                yield (start, frame.timestamp + frame.duration)
                ring_buffer.clear()
                voiced_frames = []
    # If we have any leftover voiced audio when we run out of input,
    # yield it.
    if voiced_frames:
        yield (start, frame.timestamp + frame.duration)


def VAD_chunk(aggressiveness, path):
    audio, byte_audio = read_wave(path, sr)
    vad = webrtcvad.Vad(int(aggressiveness))
    frames = frame_generator(20, byte_audio, sr)
    frames = list(frames)
    times = vad_collector(sr, 20, 200, vad, frames)
    speech_times = []
    speech_segs = []
    for i, time in enumerate(times):
        start = np.round(time[0],decimals=2)
        end = np.round(time[1],decimals=2)
        j = start
        while j + .4 < end:
            end_j = np.round(j+.4,decimals=2)
            speech_times.append((j, end_j))
            speech_segs.append(audio[int(j*sr):int(end_j*sr)])
            j = end_j
        else:
            speech_times.append((j, end))
            speech_segs.append(audio[int(j*sr):int(end*sr)])
    return speech_times, speech_segs
# Out:
# Requirement already satisfied: librosa in /opt/conda/lib/python3.7/site-packages (0.8.0)
# Collecting webrtcvad
#   Downloading webrtcvad-2.0.10.tar.gz (66 kB)
#      |████████████████████████████████| 66 kB 4.5 MB/s eta 0:00:011
# Requirement already satisfied: pooch>=1.0 in /opt/conda/lib/python3.7/site-packages (from librosa) (1.3.0)
# Requirement already satisfied: decorator>=3.0.0 in /opt/conda/lib/python3.7/site-packages (from librosa) (4.4.2)
# Requirement already satisfied: resampy>=0.2.2 in /opt/conda/lib/python3.7/site-packages (from librosa) (0.2.2)
# Requirement already satisfied: audioread>=2.0.0 in /opt/conda/lib/python3.7/site-packages (from librosa) (2.1.9)
# Requirement already satisfied: scipy>=1.0.0 in /opt/conda/lib/python3.7/site-packages (from librosa) (1.4.1)
# Requirement already satisfied: joblib>=0.14 in /opt/conda/lib/python3.7/site-packages (from librosa) (0.14.1)
# Requirement already satisfied: numpy>=1.15.0 in /opt/conda/lib/python3.7/site-packages (from librosa) (1.18.5)
# Requirement already satisfied: soundfile>=0.9.0 in /opt/conda/lib/python3.7/site-packages (from librosa) (0.10.3.post1)
# Requirement already satisfied: scikit-learn!=0.19.0,>=0.14.0 in /opt/conda/lib/python3.7/site-packages (from librosa) (0.23.2)
# Requirement already satisfied: numba>=0.43.0 in /opt/conda/lib/python3.7/site-packages (from librosa) (0.49.1)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.7/site-packages (from numba>=0.43.0->librosa) (46.1.3.post20200325)
# Requirement already satisfied: llvmlite<=0.33.0.dev0,>=0.31.0.dev0 in /opt/conda/lib/python3.7/site-packages (from numba>=0.43.0->librosa) (0.31.0)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.7/site-packages (from pooch>=1.0->librosa) (20.1)
# Requirement already satisfied: requests in /opt/conda/lib/python3.7/site-packages (from pooch>=1.0->librosa) (2.23.0)
# Requirement already satisfied: appdirs in /opt/conda/lib/python3.7/site-packages (from pooch>=1.0->librosa) (1.4.3)
# Requirement already satisfied: six>=1.3 in /opt/conda/lib/python3.7/site-packages (from resampy>=0.2.2->librosa) (1.14.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.7/site-packages (from scikit-learn!=0.19.0,>=0.14.0->librosa) (2.1.0)
# Requirement already satisfied: cffi>=1.0 in /opt/conda/lib/python3.7/site-packages (from soundfile>=0.9.0->librosa) (1.14.0)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.7/site-packages (from cffi>=1.0->soundfile>=0.9.0->librosa) (2.20)
# Requirement already satisfied: pyparsing>=2.0.2 in /opt/conda/lib/python3.7/site-packages (from packaging->pooch>=1.0->librosa) (2.4.7)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/lib/python3.7/site-packages (from requests->pooch>=1.0->librosa) (2.9)
# Requirement already satisfied: chardet<4,>=3.0.2 in /opt/conda/lib/python3.7/site-packages (from requests->pooch>=1.0->librosa) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/conda/lib/python3.7/site-packages (from requests->pooch>=1.0->librosa) (1.25.9)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.7/site-packages (from requests->pooch>=1.0->librosa) (2020.12.5)
# Building wheels for collected packages: webrtcvad
#   Building wheel for webrtcvad (setup.py) ... done
#   Created wheel for webrtcvad: filename=webrtcvad-2.0.10-cp37-cp37m-linux_x86_64.whl size=93084 sha256=34ef664c4475a819f8c1b81f5ce795d1178d8dd0356c199a8c5dda7a8f1c64f8
#   Stored in directory: /workspace/.cache/pip/wheels/11/f9/67/a3158d131f57e1c0a7d8d966a707d4a2fb27567a4fe47723ad
# Successfully built webrtcvad

# %%
import numpy as np
def concat_both(times, segs):
    """Concatenate continuous times and their segments"""
    concat_seg = []
    concat_times = []
    seg_concat = segs[0]
    time_concat = times[0]
    for i in range(0, len(times)-1):
        if time_concat[1] == times[i+1][0]:
            seg_concat = np.concatenate((seg_concat, segs[i+1]))
            time_concat = (time_concat[0], times[i+1][1])
        else:
            concat_seg.append(seg_concat)
            seg_concat = segs[i+1]
            concat_times.append(time_concat)
            time_concat = times[i+1]
    else:
        concat_seg.append(seg_concat)
        concat_times.append(time_concat)
    return concat_times, concat_seg

# %%
def make_dataset(concat_times, concat_segs):
  starts = [s[0] for s in concat_times]
  ends = [s[1] for s in concat_times]
  return {'start': starts,
          'end': ends,
          'speech': concat_segs}

# %%
# !pip install datasets
from datasets import Dataset

def vad_to_dataset(path):
  t,s = VAD_chunk(3, path)
  ct, cs = concat_both(t, s)
  dset = make_dataset(ct, cs)
  return Dataset.from_dict(dset)

# %%
! pip install -q transformers

# %%
from transformers import Wav2Vec2Processor, Wav2Vec2ForCTC
# load model and tokenizer
processor = Wav2Vec2Processor.from_pretrained("mbien/wav2vec2-large-xlsr-polish")
model = Wav2Vec2ForCTC.from_pretrained("mbien/wav2vec2-large-xlsr-polish")
model.to("cuda")

# %%
def speech_file_to_array_fn(batch):
    import torchaudio
    speech_array, sampling_rate = torchaudio.load(batch["path"])
    batch["speech"] = speech_array[0].numpy()
    batch["sampling_rate"] = sampling_rate
    batch["target_text"] = batch["sentence"]
    return batch
def evaluate(batch):
  import torch
  inputs = processor(batch["speech"], sampling_rate=16_000, return_tensors="pt", padding=True)

  with torch.no_grad():
    logits = model(inputs.input_values.to("cuda"), attention_mask=inputs.attention_mask.to("cuda")).logits

  pred_ids = torch.argmax(logits, dim=-1)
  batch["pred_strings"] = processor.batch_decode(pred_ids)
  return batch

# %%
import json
def process_wave(filename):
  dataset = vad_to_dataset(filename)
  result = dataset.map(evaluate, batched=True, batch_size=16)
  speechless = result.remove_columns(['speech'])
  d=speechless.to_dict()
  tlog = list()
  for i in range(0, len(d['end']) - 1):
    out = dict()
    out['start'] = d['start'][i]
    out['end'] = d['end'][i]
    out['transcript'] = d['pred_strings'][i]
    tlog.append(out)
  with open('{}.tlog'.format(filename), 'w') as outfile:
    json.dump(tlog, outfile)

# %%
import glob
for f in glob.glob('./*.wav'):
  process_wave(f)
